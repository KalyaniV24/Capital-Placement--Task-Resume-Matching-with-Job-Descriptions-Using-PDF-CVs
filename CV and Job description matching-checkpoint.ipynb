# %%
import os
from PyPDF2 import PdfReader
import re

# Define a function to extract key details from a PDF file
def extract_details(pdf_file):
    # Open the PDF file
    with open(pdf_file, 'rb') as pdf:
        pdf_reader = PdfReader(pdf)
        
        # Initialize variables to store extracted details
        category = None
        skills = None
        education = None

        # Combine all text from the PDF
        all_text = ''.join(page.extract_text() for page in pdf_reader.pages)

        # Extract Category (Job Role)
        category_match = re.search(r'(.+?)\nExperience', all_text)
        if category_match:
            category = category_match.group(1).strip()

        # Extract Skills
        skills_match = re.search(r'Skills\n(.*?)\n', all_text)
        if skills_match:
            skills = skills_match.group(1).strip()

        # Extract Education (Degree and Institution)
        education_match = re.search(r'Education\n(.*?)\n', all_text)
        if education_match:
            education = education_match.group(1).strip()

        return {
            'Category': category,
            'Skills': skills,
            'Education': education
        }

# Specify the path to the main folder containing subfolders for different job categories
main_folder = r'C:\Users\Lenovo\Downloads\archive (1)\data\data'

# Initialize a dictionary to store resume details for each job category
job_details = {}

# Traverse through subdirectories
for job_category in os.listdir(main_folder):
    job_folder = os.path.join(main_folder, job_category)

    # Ensure that it's a directory
    if os.path.isdir(job_folder):
        # List all PDF files in the job category folder
        pdf_files = [os.path.join(job_folder, filename) for filename in os.listdir(job_folder) if filename.endswith('.pdf')]

        # Extract details from each PDF file and store them in a list
        resume_details = []
        for pdf_file in pdf_files:
            details = extract_details(pdf_file)
            resume_details.append(details)

        # Store the resume details for this job category in the dictionary
        job_details[job_category] = resume_details

# Print the extracted details for each job category
for job_category, details_list in job_details.items():
    print(f"Job Category: {job_category}")
    for i, details in enumerate(details_list):
        print(f"Resume {i + 1} Details:")
        print("Category:", details['Category'])
        print("Skills:", details['Skills'])
        print("Education:", details['Education'])
        print("\n")
# Out:
# Job Category: ACCOUNTANT
# Resume 1 Details:
# Category: deobligate over $5M in duplicate obligations.
# Skills: None
# Education: Northern Maine Community College
#
#
# Resume 2 Details:
# Category: Business Administration Finance
# Skills: accounting, accounts payable, Accounts Receivable, ADP, advertising, AR, balance sheet, balance, bank reconciliations, benefits, billing, billings,
# Education: Bachelor of Science
#
#
# Resume 3 Details:
# Category: Customer Service
# Skills: accounts payables, accounts receivables, Accounts Payable, Accounts Receivable, administrative functions, trial balance, banking, budget, bi,
# Education: Computer Applications Specialist Certificate Program
#
#
# Resume 4 Details:
# Category: SENIOR ACCOUNTANT
# Skills: accounting, balance sheet, budgets, client, clients, derivatives, drafting, equity, financial, financial accounting, financial statements, fixed assets,
# Education: EMORY UNIVERSITY, Goizueta Business School
#
#
# Resume 5 Details:
# Category: None
# Skills: Aderant/CMS
# Education: Bachelor of Business Administration
#
#
# Resume 6 Details:
# Category: None
# Skills: Internet and Microsoft Office - MS Word, MS Power Point, MS Excel, Pivot Tables, Spreadsheets,
# Education: Master of Business Administration
#
#
# Resume 7 Details:
# Category: transactions.
# Skills: 3d, accounting, Accountant, Accounts receivables, Adobe Illustrator, Adobe Photoshop, Pagemaker, Audio Editing, auditing, banking, book,
# Education: 2006
#
#
# Resume 8 Details:
# Category: Employ natural leadership and interpersonal skills to build relationships throughout the organization.
# Skills: None
# Education: Bachelor of Science
#
#
# Resume 9 Details:
# Category: None
# Skills: Superior attention to detail
# Education: Bachelor of Science Degree
#
#
# Resume 10 Details:
# Category: Sarbanes-Oxley Research and Compliance
# Skills: accounting, Accounting Systems, ad, analytical skills, auditing, automation, billing, budgeting, budgets, Budget, business operations, business
# Education: BS
#
#
# Resume 11 Details:
# Category: None
# Skills: Accounting, Accounting Systems, AIA, AS400, Billings, Bluebeam,Bonds, Budgets, Business Management, Clerical, Construction Management,
# Education: USM - GRAPHIC DESIGN, REAL ESTATE and NVCC-ARCHITECTURAL DRAFTING
#
#
# Resume 12 Details:
# Category: Advanced computer proficiency (PC and Mac)
# Skills: Budget forecasting expertise
# Education: None
#
#
# Resume 13 Details:
# Category: None
# Skills: Microsoft Office
# Education: Bachelor of Science
#
#
# Resume 14 Details:
# Category: Deadline-oriented
# Skills: Full Accounting cycle
# Education: None
#
#
# Resume 15 Details:
# Category: Internal and external auditing
# Skills: Microsoft Word/Excel Â  Â  Â  Â
# Education: MERCY COLLEGE
#
#
# Resume 16 Details:
# Category: UTShare
# Skills: Grant management
# Education: Prairie View A & M University
#
#
# Resume 17 Details:
# Category: Global Solutions Systems), People Soft, SAP, Quicken, Nanovision, 2-Tier, Phoenix (E1), and Business Objects.
# Skills: Account reconciliations, accounting, accounts payable, accounts receivables, accruals, ad, AP, balance sheet, balance, bank reconciliations, billing,
# Education: Master of Business Administration
#
#
# Resume 18 Details:
# Category: PDF: Adobe Reader / Adobe Acrobat X
# Skills: Accounting Software:
# Education: 2005
#
#
# Resume 19 Details:
# Category: superior results.
# Skills: Operated computers programmed with accounting software to record, store, and analyze information.
# Education: Diploma
#
#
# Resume 20 Details:
# Category: Timberline, AS400)
# Skills: Training, Fairbanks, AK
# Education: A.A.
#
#
# Resume 21 Details:
# Category: Edwards/AS 400, Microsoft Accounting Office, Image Freeway, QuickBooks, SAP, LX, SAGE
# Skills: account reconciliations, Accounting, accruals, ad, AS 400, balance sheet, balance sheets, budgets, budget, controller, Corporate Finance, ERP,
# Education: None
#
#
# Resume 22 Details:
# Category: Work History
# Skills: accounting system, Accounts Payable, Administrative support, agency, auditing, budget, clerical, Closing, conferences, Contracts, copying, client,
# Education: Bachelor of Science
#
#
# Resume 23 Details:
# Category: Summary
# Skills: Microsoft Excel expert - Pivot Tables, V-Lookups, Formulas
# Education: MBA
#
#
# Resume 24 Details:
# Category: SAP Financials, Oracle Financials, PeopleSoft, Cognos Budgeting System, Microsoft Office, Advanced Excel
# Skills: None
# Education: University of Phoenix
#
#
# Resume 25 Details:
# Category: Re-modeled divisional comparison in P&L.
# Skills: Communication Skills: Â Taking initiative in communication among team members by interacting with people from diverse cultural
# Education: 2010
#
#
# Resume 26 Details:
# Category: MS Office
# Skills: Accounting, administrative, agency, audit report, backup, bank reconciliations, basic, billing, budgets, cash register, Cashier, Catalog, clerical,
# Education: Bachelor Business Administration
#
#
# Resume 27 Details:
# Category: None
# Skills: 15+ years of experience in Accounting & Bookkeeping
# Education: Bachelor
#
#
# Resume 28 Details:
# Category: Account reconciliation expert
# Skills: Organization - managing responsibilities in a particular manner and keeping track of those responsibilities.
# Education: Select
#
#
# Resume 29 Details:
# Category: SENIOR ACCOUNTANT
# Skills: Power User of Microsoft Excel Epicor NetSuite QuickBooks Hyperion Great Plains Sage Intacct,
# Education: Bachelor of Business Administration
#
#
# Resume 30 Details:
# Category: None
# Skills: Accounting, billing, Change Management, contracts, Client Relations, Database, delivery, Eclipse, Finance, financial reporting, financial statements,
# Education:
#
#
# Resume 31 Details:
# Category: applications with very good typing speed.
# Skills: Accounting, Accounting Software, Accounts Payables, accounts payable, Accounts Receivables, accrual, administrative, administrative support,
# Education: M.Com (Master of Commerce)
#
#
# Resume 32 Details:
# Category: None
# Skills: Analytical reasoning
# Education: None
#
#
# Resume 33 Details:
# Category: Desktop Publishing Software: Photoshop, Illustrator, HTML
# Skills: Accounts receivable professional
# Education: None
#
#
# Resume 34 Details:
# Category: Netscape Messenger
# Skills: Accounting, Accounts payable, Accounts Receivable, accruals, acquisitions, billing, closing, Consulting, contracts, Controller, credit, Customer
# Education: Master
#
#
# Resume 35 Details:
# Category: None
# Skills: accounting, Accountant, Arabic, Balance Sheet, bank reconciliations, com, resolve customer complaints, Customer Service, databases, delivery,E-mail, English, expense reports, Financial, Financial and accounting, financial statements, forms, general ledger, Lecturer, excel, office, Microsoft
# Education: May 2010
#
#
# Resume 36 Details:
# Category: FCR: Online Application for financial transactions.
# Skills: accounting, accountant, administrative, Army, Agency, backup, book, budget, Business Administration, cash flow, contracts, DC, documentation,
# Education: 1 2016
#
#
# Resume 37 Details:
# Category: State
# Skills: NetSuite, Epicor, Sage, Quickbooks, Office Master System, Peachtree, GLACIER Tax Prep, Intuit Payroll, ChasePaymentech, Word, Excel,
# Education: Ball State University
#
#
# Resume 38 Details:
# Category: Accomplishments, Honors, and Activities
# Skills: Accounting, Sales, Inventory, Payroll, The Accounting, Reconciliations, Bookkeeper, Audits, Operations, Ap, Ar, Assembly, Closings, Contracts,
# Education: Master of Arts
#
#
# Resume 39 Details:
# Category: Saved over $20,000 as a result of a Worker's Compensation Insurance, Sales and Use Tax Audit.
# Skills: Attention to Detail goal oriented Accounts payable, receivable, manager
# Education: Bachelor of Science
#
#
# Resume 40 Details:
# Category: [area]
# Skills: Results-oriented
# Education: None
#
#
# Resume 41 Details:
# Category: Flexible team player
# Skills: Microsoft Office (Word, Excel, Power Point, Outlook)
# Education: Bachelor of Science
#
#
# Resume 42 Details:
# Category: & Generally Accepted Auditing Standards (GAAS/SAS No.)
# Skills: QuickBooks, Sage, Lacerte, and Intuit ProSeries (well-rounded on the applications and functions), Microsoft Suite (Word (Advanced), Excel
# Education: None
#
#
# Resume 43 Details:
# Category: dispute reporting procedures.
# Skills: account reconciliations, accounting, accounts payable, Accounts Receivable, AP, Balance sheet, Bank Reconciliation, Banking, Billing, book,
# Education: MBA (Finance and IT) *B.Com(Mgt Hons) Technical Qualifications *SAP FI
#
#
# Resume 44 Details:
# Category: Navigate within Resource one to retrieve financial reports and run queries
# Skills: account reconciliation, accounting, accountant, accounting system, AR, budget, business objects, closing, Contracts, financial, financial analysis,
# Education: May 2011Masters of Science
#
#
# Resume 45 Details:
# Category: financial statements, month and year end reporting, and budgeting
# Skills: Account reconciliation, accounting, general accounting, accounting software, accounts payables, accounts receivables, A/P, Arabic, Balance sheet,
# Education: Anticipate Degree
#
#
# Resume 46 Details:
# Category: *Knowledge of SAP system
# Skills: account reconciliation, accounting, accounts payable, accruals, accrual, balance sheet, Balance, balance sheets, bank reconciliation, benefits,
# Education: Master degree
#
#
# Resume 47 Details:
# Category: None
# Skills: None
# Education: Masters
#
#
# Resume 48 Details:
# Category: Flexible team player
# Skills: Analytical reasoning
# Education: None
#
#
# Resume 49 Details:
# Category: National Science and Technology Council.
# Skills: Financial
# Education: None
#
#
# Resume 50 Details:
# Category: Facilitated onboarding of new employees by scheduling training, answering questions and processing paperwork.
# Skills: Proficient in Microsoft Office (Excel, Word, PowerPoint)
# Education: Bachelor of Arts
#
#
# Resume 51 Details:
# Category: Human Resources *Visual Basic *ORACLE
# Skills: accounting, Accounts Payable, ADP Payroll, ad, A/P, audit reports, balance, Balance Sheet, Bank Reconciliations, Bank reconciliation, billings,
# Education: 02/2004
#
#
# Resume 52 Details:
# Category: using advanced Microsoft Excel functions.
# Skills: Account management, accounts receivables, administrative functions, administrative support, billing, billings, billing systems, clarify, hardware,
# Education: Bachelor degree
#
#
# Resume 53 Details:
# Category: Controller position.
# Skills: Accounting, Accounting Software, accruals, accrual, Ad, AP, A/P, AR, Balance Sheet, bank reconciliations, Monthly Bank Reconciliations,
# Education: Bachelor
#
#
# Resume 54 Details:
# Category: Advanced Excel skills
# Skills: Month end close, Year end close, Cash Management,
# Education: University of North Alabama
#
#
# Resume 55 Details:
# Category: None
# Skills: Strong communication skills
# Education: Master of Accounting & Financial Management
#
#
# Resume 56 Details:
# Category: finance experience.
# Skills: Work History
# Education: Master of Business Administration
#
#
# Resume 57 Details:
# Category: Teambuilding & Staff Supervision
# Skills: Accounting, accounts
# Education: Pursuing Certified Public Accountant (CPA), Boston, MA
#
#
# Resume 58 Details:
# Category: None
# Skills: Work History
# Education: Completing MS
#
#
# Resume 59 Details:
# Category: Decisive
# Skills: IT: Excel, Access
# Education: 2008
#
#
# Resume 60 Details:
# Category: None
# Skills: Proficient in Microsoft Office 2010 Access, Word, Excel, Outlook, Alpha-5, System Application Process (Sap), Windows (2007,XP, NT, 2000,
# Education: Strayer University
#
#
# Resume 61 Details:
# Category: Expert in customer relations
# Skills: None
# Education: BBA
#
#
# Resume 62 Details:
# Category: Accountant for a Medium sized Company
# Skills: accounting, CPA, local area network, Peachtree Accounting, Reporting, Web site
# Education: None
#
#
# Resume 63 Details:
# Category: May 2012-August 2012 *Maintain golf carts and driving range
# Skills: account reconciliations, accounting system, accounts payable, process payroll, spreadsheets
# Education: None
#
#
# Resume 64 Details:
# Category: transactions.
# Skills: General Accounting, accounts payable, accounts receivable, Microsoft office, Outlook, Windows XP, Word,
# Education: Accounting
#
#
# Resume 65 Details:
# Category: Summary
# Skills: Billing and Collections
# Education: None
#
#
# Resume 66 Details:
# Category: Proficient in Microsoft Windows operating systems
# Skills: Account Reconciliations, accounting, accounting systems, Accounts Receivable, accruals, AP, AR, Attention to Detail, bookkeeping, budget, cash
# Education: Certified Public Accountant
#
#
# Resume 67 Details:
# Category: Skilled in exceeding sales goals and company expectations by expanding client base and maintaining high standards of customer service. Year
# Skills: Automotive, business operations, calipers, Call center, closing, Strong interpersonal skills, Excellent communication, Strong communication skills,
# Education: 1997
#
#
# Resume 68 Details:
# Category: None
# Skills: accounting, accountant, accounts payable, accounts receivable, billing, book, CPT, finance, financial, financial/ accounting, financial statements,
# Education: UNIVERSITY OF HARTFORD
#
#
# Resume 69 Details:
# Category: Timberline, MRI, YARDI, Peachtree, Peoplesoft, OneSite, QuickBooks Microsoft Word and Excel
# Skills: Timberline, MRI, YARDI, Peachtree, Peoplesoft, OneSite, QuickBooks Microsoft Word and Excel
# Education: None
#
#
# Resume 70 Details:
# Category: Oracle Financial, PeopleSoft, Microsoft Dynamics Nav, Microsoft Office Suite, Outlook, Lotus Notes
# Skills: account reconciliation, Accounting, general accounting, accruals, ad, Agency, balance sheets, billing, budgets, Budget, charts, compliance
# Education: Masters of Science
#
#
# Resume 71 Details:
# Category: examine issues and develop best practice solutions. Currently working towards becoming a CPA.
# Skills: Account reconciliations, accounting software, accounts payable, Bank Reconciliations, filing, financial reports, Financial Statement Preparation,
# Education: None
#
#
# Resume 72 Details:
# Category: Assisted in the managing of the company database and verified, edited and modified members' information.
# Skills: Professional and friendly
# Education: 2013
#
#
# Resume 73 Details:
# Category: None
# Skills: Microsoft AX Dynamics
# Education: None
#
#
# Resume 74 Details:
# Category: Lawson, Invision, QuickBooks, MS Word, Excel, PowerPoint, Lotus Notes, and Meditech
# Skills: Lawson, Invision, QuickBooks, MS Word, Excel, PowerPoint, Lotus Notes, and Meditech
# Education: None
#
#
# Resume 75 Details:
# Category: STAFF ACCOUNTANT
# Skills: Accounting, Accountant, Accounts Payable, balance sheet, Budget Planning, CMS, Controller, credit, data mining, senior management, Finance,
# Education: IRS 990 Tax Reporting & Submission
#
#
# Resume 76 Details:
# Category: Syteline (Manufacturing
# Skills: ISO9001, Team Lead, Logistics, MAPICS, Excel, Outlook, Power Point, Word, Works, QuickBooks,
# Education: Graduate Diploma
#
#
# Resume 77 Details:
# Category: more accurate cash-forecasting system.
# Skills: None
# Education: High School Diploma
#
#
# Resume 78 Details:
# Category: Syspro (ERP program)
# Skills: Microsoft Office Excel, Outlook and Word, SAGE 100, Ramp (WMS software) and
# Education: None
#
#
# Resume 79 Details:
# Category: SAP, Great Plains Dynamics, Sage50, QuickBooks Pro, ACT, Microsoft Word, Excel (Pivot tables and VLook Up) Access, PowerPoint
# Skills: SAP, Great Plains Dynamics, Sage50, QuickBooks Pro, ACT, Microsoft Word, Excel (Pivot tables and VLook Up) Access, PowerPoint
# Education: None
#
#
# Resume 80 Details:
# Category: SAP AS400 CAMS Microsoft Office Suite
# Skills: Accounting, Accounts Payable, accruals, AP, AS400, automotive, trial balance, balance sheets, Bank Reconciliations, benefits, budget,
# Education: 1 2009
#
#
# Resume 81 Details:
# Category: None
# Skills: Microsoft Office - Advanced knowledge and skill
# Education: Computer Science
#
#
# Resume 82 Details:
# Category: Build & design web pages and desktop applications. Department: HR.
# Skills: Visual Basic .Net, Accounting, photo, advertising, Arabic, budgets, business administration, conferences, databases, English, exhibitions, Fast,
# Education: Middle East Language School (MES)
#
#
# Resume 83 Details:
# Category: Formally recognized for excellence achieved in financial analysis, budgeting and forecasting.
# Skills: Proficient in Microsoft Office Suite, Access, QuickBooks, Turbo Tax, Vision Accounting Software, Peach Tree,
# Education: 8 2013
#
#
# Resume 84 Details:
# Category: Property Management & Lease Accounting
# Skills: Month-end close activities - Reconciliations/Analysis
# Education: None
#
#
# Resume 85 Details:
# Category: enforcement and implementation of a new quality control system.
# Skills: account reconciliation, accounting system, AR, budget, business objects, closing, Contracts, Â financial analysis, financial controls, financialoperations, financial reports, financial statements, GL, Grants, inventory, invoicing, ledger, Macros, Access, Excel, Microsoft Office, office,
# Education: Masters of Science
#
#
# Resume 86 Details:
# Category: Budget analysis
# Skills: USGAAP principles
# Education: Bachelor
#
#
# Resume 87 Details:
# Category: None
# Skills: Self-motivated
# Education: Bachelor of Business Administration Degree
#
#
# Resume 88 Details:
# Category: Accounting and Financial Reporting
# Skills: Accounting and Financial Reporting
# Education: 2012
#
#
# Resume 89 Details:
# Category: Achieved the Chief Financial Officer (CFO) certification through the Michigan School Business Officials organization.Â
# Skills: Creative problem solving skills.
# Education: BBA
#
#
# Resume 90 Details:
# Category: Improved customer relations.
# Skills: Good Communication
# Education: Certificate
#
#
# Resume 91 Details:
# Category: Served on the Core Process Review Team.
# Skills: Computer Applications
# Education: Ashford University
#
#
# Resume 92 Details:
# Category: Understands grammar
# Skills: Excel spreadsheets
# Education: None
#
#
# Resume 93 Details:
# Category: Superior research skills
# Skills: Microsoft Office
# Education: None
#
#
# Resume 94 Details:
# Category: Compiles information and Assists in preparing Annual Budget utilizing Microsoft Office, QuickBooks & Excel
# Skills: Income Statement, Balance Sheet, Budget expense vs. Actual Expense, when necessary prepare Income Statements for Special Events
# Education: None
#
#
# Resume 95 Details:
# Category: None
# Skills: Oracle Accounting
# Education: MBA
#
#
# Resume 96 Details:
# Category: Excel, Word
# Skills: None
# Education: Bachelor of Science
#
#
# Resume 97 Details:
# Category: None
# Skills: Account reconciliation specialist
# Education: Bachelor of Science
#
#
# Resume 98 Details:
# Category: Account reconciliation expert
# Skills: accounting, Accounting software, accounting system, Accounts Payable and Receivable, accounts receivables, AP, AR, AS 400, balance sheet,
# Education: Bachelor of Science
#
#
# Resume 99 Details:
# Category: Email: Outlook and Lotus note
# Skills: Academic, Account reconciliation, Accounting, accountant, Accounting Systems, Accounts payable, Accounts Payables, accounts receivable,
# Education: MBA Degree
#
#
# Resume 100 Details:
# Category: to develop streamlined way to track paid time off.Simplified payroll processing procedure to increase department productivity by 25%.
# Skills: accounting software, accounts payable, ADP 5.30, ADP, benefits, budgets, Ceridian, Contracts, documentation, Edge, Equity, forms, funds,
# Education: MBA
#
#
# Resume 101 Details:
# Category: including Microsoft Word, PPT, Microsoft Excel II and Access III
# Skills: Accounting, approach, AS400, auditing, bank reconciliations, competitive, contracts, CRM, clientele, clients, customer satisfaction, customer
# Education: 5 2015
#
#
# Resume 102 Details:
# Category: Motivated, enthusiastic and cheerful seeking a position that involves community, assisting city residence and positively interacting with people.
# Skills: BudgetÂ Analsis
# Education: 2008
#
#
# Resume 103 Details:
# Category: Reports(currently SAP Crystal Reports); Hyperion Essbase
# Skills: Netsuite; Quickbooks; Cognos Impromptu; JDEdwards; AS400; Sage FAS Fixed Assets; BNA Fixed Assets; BusinessObjects Crystal
# Education: Bachelor of Science
#
#
# Resume 104 Details:
# Category: Dean's List
# Skills: Credit, Purchase Orders, Accounts Payable, File, Million, Sales, Sales And, Sales Tax, Tax Returns, Collections, Litigation, Loans, Team Lead,
# Education: Bachelor of Arts
#
#
# Resume 105 Details:
# Category: Microsoft Publisher Knowledge
# Skills: Communication Skills
# Education: MBA
#
#
# Resume 106 Details:
# Category: expert level
# Skills: Accounting, A/P, auditing, balance sheet, Bank Reconciliations, billing, budget, business operations, business processes, contracts, clients, decision
# Education: University of South Florida
#
#
# Resume 107 Details:
# Category: Financial records and processing
# Skills: account reconciliation, Accounting, accountant, accrual, ABC, Streamline, ADP and Payroll, Ad, AP, AR, Balance Sheet, billings, Biotechnology,
# Education: Summer 2017
#
#
# Resume 108 Details:
# Category: Working knowledge in Delta Software Doha Qatar Proficiency in Microsoft Â​ Office
# Skills: Reconcile balance sheet accounts, account reconciliations, Accounting, Accountant I, Accountant, accounting system, Accounts Payable and
# Education: Master of Business Administration (MBA)
#
#
# Resume 109 Details:
# Category: None
# Skills: Accounting operations professional
# Education: Bachelor of Science
#
#
# Resume 110 Details:
# Category: solving
# Skills: 10 key by touch, Accounting software, Accounts Payable, Accounts Receivable, administrative, AIA, AS400, billing, billings, Controller, draw,
# Education: None
#
#
# Resume 111 Details:
# Category: At other businesses I helped implement several different accounting software solutions.
# Skills: Account reconciliations, accounting, accountant, Accounting Manager, accounts payable, accounts receivable, administrative, artist, Art,
# Education: 1985
#
#
# Resume 112 Details:
# Category: Summary
# Skills: Account Management, accounts payable, accounts receivable, administrative, ADP, A/P, Bank Reconciliation, Basic, Billing, Closing, CMS,
# Education: City University of New York, Brooklyn College
#
#
# Resume 113 Details:
# Category: Fundstation, Nucleus, Allegro, Citrix, A/P and A/R EDMS
# Skills: Personal Information
# Education: 1 1999
#
#
# Resume 114 Details:
# Category: Boosted quality ratings by 85% by developing new processes and improving work flow.
# Skills: Accounting, balance, budget, business analyst, Call Center, Cash Management, closing, contracts, Critical Thinking, client, clients, databases,
# Education: Accounting Certificate
#
#
# Resume 115 Details:
# Category: None
# Skills: Healthcare:
# Education: None
#
#
# Resume 116 Details:
# Category: BenefitMall Payroll, Fidelity, Choice Strategies
# Skills: None
# Education: Bachelor of Arts
#
#
# Resume 117 Details:
# Category: Advanced computer proficiency (PC and Mac)
# Skills: None
# Education: Master of Business Administration
#
#
# Resume 118 Details:
# Category: Strong leadership with great attention to detail for optimal results
# Skills: ACCOUNTING, A/P, attention to detail, bank reconciliation, INTERPERSONAL, data entry, fashion, Finance, general ledger, leadership,
# Education: Bachelor of Science
#
#
# Job Category: ADVOCATE
# Resume 1 Details:
# Category: Led support groups to help parents regain and improve their parent-child bond.
# Skills: scheduling appointments
# Education: l Coursework in Organizational Behavior, Compensation, Labor Relations and Recruitment
#
#
# Resume 2 Details:
# Category: Production/Operations Supervisor Shipping/ Receiving Supervisor Customer Service Representative Excellent Written/ Verbal Communication
# Skills: None
# Education: Logistics and Supply Chain Management - Post Secondary Training Certificate
#
#
# Resume 3 Details:
# Category: Over ten years in volunteering in summer basketball camp and PADS homeless shelter.
# Skills: None
# Education: Bachelor of Arts
#
#
# Resume 4 Details:
# Category: Supervised team of three staff members.
# Skills: Administrative
# Education: High School Diploma
#
#
# Resume 5 Details:
# Category: Trauma, triage, tutoring, Urology
# Skills: care planning, Case Management, Home Health, Hospice, Infection control, injections, Nurse Manager, Oncology, scheduling, staff development,
# Education: None
#
#
# Resume 6 Details:
# Category: None
# Skills: Scheduling
# Education: Bachelor of Arts
#
#
# Resume 7 Details:
# Category: Running reports, analyzing and organizing data in Excel using pivot tables.
# Skills: account management, Agency, benefits, Billing, Cisco, Coach, Coaching, com, Counseling, Client, client relations, customer relations, Customer
# Education: Bachelor of Social Sciences
#
#
# Resume 8 Details:
# Category: Gap analysis
# Skills: Data analysis
# Education: None
#
#
# Resume 9 Details:
# Category: Flexible schedule
# Skills: None
# Education: None
#
#
# Resume 10 Details:
# Category: and records management.
# Skills: allergies, Attention to detail, CPT, clients, emotional support, forms, home health, hospice,ICD-9, ids, insurance, leadership, law, Medical
# Education: None
#
#
# Resume 11 Details:
# Category: None
# Skills: Â Conflict resolution, advocacy, group facilitation, program development, youth advocacy, outreach, Microsoft Office, training, counseling,
# Education: None
#
#
# Resume 12 Details:
# Category: Organized and efficient
# Skills: Client Relations
# Education: Bachlor of Science
#
#
# Resume 13 Details:
# Category: Cultural awareness and sensitivity
# Skills: Maintains strict confidentiality
# Education: None
#
#
# Resume 14 Details:
# Category: wellness; aided in program coordination; encouraged youth self-awareness and self-confidence.
# Skills: academic, Administrative, aims, approach, Arts, Art, Book, Council, critical thinking, database, essays, special events, Leadership, leadership
# Education: 2014
#
#
# Resume 15 Details:
# Category: None
# Skills: Phlebotomy knowledge
# Education: MBA
#
#
# Resume 16 Details:
# Category: None
# Skills: Greet, Telephone Customer Service, Cash, Credit, Sales, Vouchers, Optical, Payments, Training, Inventory, Pricing, Billing, Forecasts, Greeting,
# Education: None
#
#
# Resume 17 Details:
# Category: Â Strategic planning and client relationship management expert.
# Skills: Trained in indicators of child abuse, domesticÂ Crisis and Human trafficking
# Education: 2014
#
#
# Resume 18 Details:
# Category: None
# Skills: Strong interpersonal skills
# Education: Master of Chiropractic
#
#
# Resume 19 Details:
# Category: Call Center
# Skills: Accounting, Accounts To, Basis, Billing, Customer Inquiries, Customer Service, Inventory, Invoices, Invoicing, Payments, Receptionist, Retail
# Education: High School Diploma
#
#
# Resume 20 Details:
# Category: Highly-motivated, coaching, and analytical health insurance leader.
# Skills: quality analysis, training, teaching, mentoring, coaching, life coaching, advertising, agency, coaching, customer satisfaction, customer service,
# Education: Bachelor of Arts
#
#
# Resume 21 Details:
# Category: Multi-task management
# Skills: Training, Liaison, Federal Government,
# Education: Juris Doctor
#
#
# Resume 22 Details:
# Category: Report writing
# Skills: None
# Education: All Lines Claims Adjuster
#
#
# Resume 23 Details:
# Category: None
# Skills: advertising, cash registers, Coach, conferences, cost reduction, Credit, Resolve customer complaints, clients, delivery, directing, employee training,
# Education: None
#
#
# Resume 24 Details:
# Category: Time management
# Skills: Skills
# Education: Associate of Science
#
#
# Resume 25 Details:
# Category: Microsoft Word, Personnel, policies, presentations, safety, transportation
# Skills: Peer counseling, customer service, database, documentation, Internet Applications, Excel, e-mail, office, Outlook, Power Point, Publisher,
# Education: Associate of Science
#
#
# Resume 26 Details:
# Category: well as securing fundingÂ
# Skills: None
# Education: Designed course curriculum, including exam design and evaluation, within
#
#
# Resume 27 Details:
# Category: Excellent writing and critical thinking skills
# Skills: Clerk, Heavy Machinery, Forensic, Security, Community Outreach, Compensation, Filing, Multi-line, Multi-line Phone, Multi-line Phone System,
# Education: Masters of Science
#
#
# Resume 28 Details:
# Category: None
# Skills: None
# Education: None
#
#
# Resume 29 Details:
# Category: None
# Skills: Health promotion, nutrition counseling, exercise testing & prescription, health and fitness speaker, Microsoft Office (Excel, PowerPoint, Word)
# Education: None
#
#
# Resume 30 Details:
# Category: None
# Skills: Trained in compounding all intravenous and chemotherapy admixtures.
# Education: None
#
#
# Resume 31 Details:
# Category: None
# Skills: 10 key, Administrative Assistant, attention to detail, Billing, CPR certified, CPT, data entry, data base, delivery, diagnosis, dispatching,
# Education: None
#
#
# Resume 32 Details:
# Category: None
# Skills: approach, automation, balance, catalog, Coach, Coaching, conflict resolution, corporate training, creativity, client, direction, Educator, forms,
# Education: None
#
#
# Resume 33 Details:
# Category: None
# Skills: Excel and Google Sheets
# Education: Bachelor of Arts
#
#
# Resume 34 Details:
# Category: Reliable transportation
# Skills: None
# Education: Master of Education
#
#
# Resume 35 Details:
# Category: Provided suggestions and helped to develop a formal plan for the reconstruction of a local Bloomington restaurant.
# Skills: Chinese, Conferences, Clients, English, Meetings, Access, Excel, Microsoft Office, PowerPoint, Word, Business Presentations, Progress, Quality,
# Education: Indiana University Bloomington
#
#
# Resume 36 Details:
# Category: None
# Skills: account reconciliations, accounting, Accounts Payable, apollo, auditing, benefits, billing system, coach, com, Credit, client, customer satisfaction,
# Education: GED apollo-resume.co
#
#
# Resume 37 Details:
# Category: emergency care.
# Skills: Prospecting and cold calling
# Education: Master of Public Administration
#
#
# Resume 38 Details:
# Category: None
# Skills: Budgeting and financial management
# Education: 5 1991
#
#
# Resume 39 Details:
# Category: Exceeded corporate target for customer satisfaction for 4 months in a row.
# Skills: Operations Management
# Education: 2015
#
#
# Resume 40 Details:
# Category: None
# Skills: None
# Education: None
#
#
# Resume 41 Details:
# Category: that resulted in sustainability.
# Skills: administrative support, Counseling, creativity, client, clients, Customer services, Data Entry, database, event planning, financial, fund raising,
# Education: Bachelor's Degree
#
#
# Resume 42 Details:
# Category: Faulkner
# Skills: â€¢Problem solving
# Education: BBA
#
#
# Resume 43 Details:
# Category: Inventory reduced project from desktops linux converstion into WINDOWS
# Skills: Customer Service
# Education: 2008
#
#
# Resume 44 Details:
# Category: inquiries specialist
# Skills: Computer literate, telephone skills, creative problem solving, resolving cash receipt discrepancies.
# Education: High School Diploma
#
#
# Resume 45 Details:
# Category: LEAD PHARMACY TECHNICIAN ADVOCATE - SUPERVISOR
# Skills: streamline, basic, budget, business development, Maintain calendar, Case Management, charts, communication skills, customer service, data entry,
# Education: Bachelors
#
#
# Resume 46 Details:
# Category: Received Employee of the Month on multiple occasions.
# Skills: Excellent communication, computer skills, copying, counseling, data entry,
# Education: No Degree
#
#
# Resume 47 Details:
# Category: Received Letter of Recognition and Letter of Accomplishment from the MN DOC Warden for correctional excellence
# Skills: Public Relations, Case Management, Client Advocacy
# Education: Sociology Leadership Studies
#
#
# Resume 48 Details:
# Category: of SAS and R.
# Skills: Word programs (including Excel and Access), EPIC and other
# Education: None
#
#
# Resume 49 Details:
# Category: Interpersonal skills
# Skills: Customer service
# Education: None
#
#
# Resume 50 Details:
# Category: Data Collection, Data Entry, Documentation, Email, Typing, Microsoft Excel, Microsoft Office Suite, Microsoft Outlook
# Skills: Client relations specialist
# Education: None
#
#
# Resume 51 Details:
# Category: None
# Skills: Handle cash, Coaching, credit, customer satisfaction, customer service, delivery, inventory, Mentoring, merchandising, networking, organizing,
# Education: Bachelors of Science
#
#
# Resume 52 Details:
# Category: Strong work ethics
# Skills: Certificate received on June 22, 2000.
# Education: Bachelor of Science
#
#
# Resume 53 Details:
# Category: WPM Patient scheduling Microsoft Office Suite Quality assurance Misys Tiger Medical Software proficient
# Skills: Associate, Cash, Cash Register, Credit, Credit Card, Database, Greetings, Its, New Sales, Sales, Sales Associate, Sales Associates, Telephone,Administrative Tasks, Operations, Ordering, 50 Wpm, Archiving, Billing, Correspondence, Data Archiving, Filing, Microsoft Office, Ms Office,
# Education: American Military University
#
#
# Resume 54 Details:
# Category: None
# Skills: Scheduling
# Education: Associate of Arts
#
#
# Resume 55 Details:
# Category: None
# Skills: Epic certifications in Resolute Hospital Billing, Home Health and SBO
# Education: None
#
#
# Resume 56 Details:
# Category: Exceeded corporate target for customer satisfaction for nine months in a row.
# Skills: DOMS applications, AS/400, Microsoft applications, outlook, Lync
# Education: Bachelor's Degree
#
#
# Resume 57 Details:
# Category: Detail Oriented, ability to maintain confidentiality
# Skills: Conflict resolution skills
# Education: Master of Science
#
#
# Resume 58 Details:
# Category: None
# Skills: Balance, Benchmarking, BTS, budget, Contracts, Council, Counseling, customer satisfaction, databases, database, delivery, Facilities
# Education: Missouri Institute of Technology
#
#
# Resume 59 Details:
# Category: Increased client engagement in all Active Health products and services sales by 98%. each quarter.
# Skills: basic, benefits, cash receipts, counseling, credit, client, customer service, staff training, financial, firing, hiring, inventory, leadership, materials,
# Education: Bachelor's Degree
#
#
# Resume 60 Details:
# Category: Took three under performing stores from negative EBITA to positive EBITA performance in under 12 months.
# Skills: Training, Recruiting, Sales, Sales Goals, Cpr, Therapeutic, Teaching, And Sell, Assistant Director, Basis, Writing Skills, Audits, Budgets, Financial
# Education: Bachelor's
#
#
# Resume 61 Details:
# Category: Professional Summary
# Skills: Persuasive negotiator
# Education: Some College (No Degree)
#
#
# Resume 62 Details:
# Category: None
# Skills: Public Safety
# Education: Bachelor of Science
#
#
# Resume 63 Details:
# Category: Proficient in using mobile devices for email, Lync and other tasks required
# Skills: academic, Active Directory, anti-virus, audio, cables, cabling, hardware upgrades, computer hardware, client, clients, Database, documentation,
# Education: High School Diploma
#
#
# Resume 64 Details:
# Category: Surgical Sterile field.Standard first aid G-Tube feedings, Foley care, IV management, wound care, etc.
# Skills: Skills Used
# Education: None
#
#
# Resume 65 Details:
# Category: None
# Skills: allergies, blood draws, budget, charts, coaching, CPR, decision making, EKGs, equipment maintenance, filling, financial, first aid, health education,
# Education:
#
#
# Resume 66 Details:
# Category: None
# Skills: Executive Level, Operations, Proposals,Â Coaching, Teaching,Â Quality Control, Corrective Action, Human Resources, Strategic Planning,
# Education: B.A.
#
#
# Resume 67 Details:
# Category: None
# Skills: anatomy, basic, Billing, call center, charts, Interpersonal, CA, customer service, Data entry, decision making, delivery, Documentation, EKG's,
# Education: None
#
#
# Resume 68 Details:
# Category: I AM FLIXILBEL AND HARD WORKING .
# Skills: administrative, administrative duties, agency, case management, client, clients, customer satisfaction, database, Fluent in English, English, Farsi,
# Education: Bachelor of Academic Law
#
#
# Resume 69 Details:
# Category: ORGANIZER AND CAPACITY BUILDING STRATEGIST
# Skills: agency, attorney, business plans, consultant, client, clients, detail oriented, grant proposals, legal, materials, organizing, policies, press releases,
# Education: JD
#
#
# Resume 70 Details:
# Category: None
# Skills: Â
# Education: None
#
#
# Resume 71 Details:
# Category: None
# Skills: Have Directors Credential .
# Education: 2014
#
#
# Resume 72 Details:
# Category: Supported SVP through personal document management, calendar organization and collateral preparation for meetings.
# Skills: Decision making
# Education: Master of Science
#
#
# Resume 73 Details:
# Category: Summary
# Skills: Strong clerical, management, and administrative skills
# Education: Bachelor of Arts
#
#
# Resume 74 Details:
# Category: multidisciplinary Professionals.
# Skills: Excellent communication skills, Investigative skill, Customer Service skills, Data Entry, documentation, inventory clerk, leadership skills,
# Education: Bachelors of Arts Degree
#
#
# Resume 75 Details:
# Category: .Culturally competent
# Skills: Compassionate
# Education: 2015
#
#
# Resume 76 Details:
# Category: Managed a caseload of more thanÂ fifty to forty-fiveÂ clients at any given time.
# Skills: None
# Education: 2004
#
#
# Resume 77 Details:
# Category: None
# Skills: Cash handling
# Education: None
#
#
# Resume 78 Details:
# Category: None
# Skills: 3G, BTS, Central point of contact, hardware, data collection, database, documentation, engineer, senior management, features, FSA, functional,
# Education: Bachelor of Science
#
#
# Resume 79 Details:
# Category: Student Co-ordinator of the ILS Free Legal Aid Society for the years 2010-2012.
# Skills: business operations, C, contracts, Credit, clients, documentation, Drafting, Finance, financing, financial, funds, insurance, Law, legal, legal
# Education: Post Graduation Diploma
#
#
# Resume 80 Details:
# Category: None
# Skills: accounts payables, accounts receivables, administrative, benefits, billing, oral, customer service, customer support, database, documentation,
# Education: None
#
#
# Resume 81 Details:
# Category: Background checks
# Skills: administrative, benchmarking, budgets, call center, Coaching, counseling, Customer Satisfaction, customer-service,
# Education: B.A
#
#
# Resume 82 Details:
# Category: Mostly Microsoft Excel and Microsoft Word
# Skills: Microsoft Word
# Education: None
#
#
# Resume 83 Details:
# Category: events for groups of 10+ employees.
# Skills: Experience with Epic System, Epicare, Emdeon, Training and educating staff on Epic WQ's, Creating Workers Comp cases in Epic, Signature,
# Education: 6 1990
#
#
# Resume 84 Details:
# Category: Assists with supervising and directing the work of community service workers and volunteers.
# Skills: 10 key, adding machine, approach, agency, banking, basic, bonds, case management, cash handling, clerical, conflict resolution, Copying,
# Education: High School Diploma
#
#
# Resume 85 Details:
# Category: Human Services
# Skills: None
# Education: August 2012
#
#
# Resume 86 Details:
# Category: Orientation Disc Personality Assessments Training and Development Leadership Development Performance Appraisals Technical Skills
# Skills: Experience
# Education: Bachelor of Science
#
#
# Resume 87 Details:
# Category: and following through to achieve project goals.Â
# Skills: Microsoft Office: Word, Excel, Power Point, Outlook * Programs: AIMsi, OMS Systems, UPS Worldship and ALICE, Apricot. * Type 40
# Education: 1995
#
#
# Resume 88 Details:
# Category: None
# Skills: Fluent in conversational Spanish
# Education: None
#
#
# Resume 89 Details:
# Category: Active in maintaining an employer of choice work environment that renders third party representation obsolete.
# Skills: Human Resources, Training, Employee Relations, Recruitment, Organizational Development, Payroll, Purchasing,
# Education: Masters
#
#
# Resume 90 Details:
# Category: NC
# Skills: acquisitions, agency, Billing, Billings, clerical, Coach, coaching, clients, email, Senior Management, filing, financial, Hiring, Human Resources, HR,
# Education: None
#
#
# Resume 91 Details:
# Category: Professional Summary
# Skills: Networking and Partnership Development
# Education: Business Administration
#
#
# Resume 92 Details:
# Category: None
# Skills: streamline, budget, interpersonal skills, Computer-literate, contracts, CPR, notes, managing, meetings, Mental Health, organizational skills,
# Education: None
#
#
# Resume 93 Details:
# Category: None
# Skills: Leadership
# Education: Bachelor's Degree
#
#
# Resume 94 Details:
# Category: Microsoft Office
# Skills: Results-oriented
# Education: None
#
#
# Resume 95 Details:
# Category: to failure events, allowing the system to stay available during random, unexpected software problems and also configured to react to system events.
# Skills: Aix, Security, Linux, Hacmp, Veritas, Websphere, Maintenance, Network File System, Nfs, Oracle, Unix, Systems Administration, Dns, Veritas
# Education: None
#
#
# Resume 96 Details:
# Category: None
# Skills: I am confident in my ability to navigate computers, communicate effectively, value teamwork, respect all members of the healthcare team, value all
# Education: Master of Science
#
#
# Resume 97 Details:
# Category: Satisfaction ratings by 100% by implementing a new user-friendly interface.
# Skills: accounting, approach, agency, backup, BUSINESS MANAGEMENT, Call Center, coaching, Competitive, contracts, cost control, clientele,
# Education: B.S
#
#
# Resume 98 Details:
# Category: None
# Skills: calculators, cash registers, closing, cooking, credit, funds, Inventory, Issue receipts, mark, money, windows, nice, paint, policies, quality, Maintain
# Education: None
#
#
# Resume 99 Details:
# Category: None
# Skills: Accounts payable and receivable,
# Education: None
#
#
# Resume 100 Details:
# Category: None
# Skills: None
# Education: None
#
#
# Resume 101 Details:
# Category: Credit card processing
# Skills: Customer service expert
# Education: None
#
#
# Resume 102 Details:
# Category: CUSTOMER CARE ADVOCATE
# Skills: Creative problem solver MS Windows proficient
# Education: High School Diploma
#
#
# Resume 103 Details:
# Category: Tax preparation
# Skills: Fast data entry
# Education: None
#
#
# Resume 104 Details:
# Category: Respectable verbal and writing skills for report and assessment writing
# Skills: None
# Education: 2014
#
#
# Resume 105 Details:
# Category: combined classroom of 9th and 12th graders to educate on sports and life skills.
# Skills: Strong Work Ethnic
# Education: 2014
#
#
# Resume 106 Details:
# Category: None
# Skills: Self-motivated
# Education: 1995
#
#
# Resume 107 Details:
# Category: Surg.
# Skills: Process evaluation
# Education: High School Diploma
#
#
# Resume 108 Details:
# Category: Teaching, tutoring and counseling
# Skills: Â· Analyzed official documents in order for migrant families to receive benefits.
# Education: None
#
#
# Resume 109 Details:
# Category: None
# Skills: Premier, automate, Behavioral Health, benefits administration, contracts, Critical thinking, client, client 2, customer service, Database management,
# Education: None
#
#
# Resume 110 Details:
# Category: Proficient Microsoft Office (Word, Excel, PowerPoint, Outlook) and the Internet.
# Skills: Marketing, Clients, Product Positioning, Public Relations, Interviewing, Recruiting, Community Relations, Operations, Case Management,
# Education: University of Houston Clear Lake
#
#
# Resume 111 Details:
# Category: None
# Skills: More than 19 years experience in healthcare, business development, marketing and planning analysis.
# Education: Masters of Science
#
#
# Resume 112 Details:
# Category: None
# Skills: Detail-oriented
# Education: Bachelor of Science
#
#
# Resume 113 Details:
# Category: APOS windows at once in tandem to maximize customer flow and productivity.
# Skills: ATM, auditing, call center, cash handling, cash register, credit, client, customer satisfaction, excellent customer service, customer service, debit,
# Education: 2009
#
#
# Resume 114 Details:
# Category: None
# Skills: account management, Business Development, business operations, CISCO, International Business, logistics, Oracle, purchasing, Sales,
# Education: 2017
#
#
# Resume 115 Details:
# Category: Earned 14% on $100,000 over a six-week period.
# Skills: insurance, managing, office
# Education: None
#
#
# Resume 116 Details:
# Category: Exceptional telephone etiquette
# Skills: administrative, Army, auditing, benefits, billing, billing system, Cable, contracts, credit, client, clients, customer
# Education: Bachelor of Science
#
#
# Resume 117 Details:
# Category: Intervention
# Skills: psychology Human Behavior and Personality Disorder academic, Various agencies worked and volunteered and interned fr Mayor Bill Di Blasio
# Education: None
#
#
# Resume 118 Details:
# Category: Promoted to Call Center lead within 6 months of employment.
# Skills: Superb sales professional
# Education: None
#
#
# Job Category: AGRICULTURE
# Resume 1 Details:
# Category: None
# Skills: balance, banking, basic, charts, oral, Basic computer skills, conferences, direction, Instructor, meetings, office, organizational skills, progress,
# Education: None
#
#
# Resume 2 Details:
# Category: Joseph Sirotnak '66, Esq., Memorial Scholarship Fall 2007 and Spring 2009
# Skills: Skillful application of bench chemistry in a lab setting by adhering to standard operating procedures.
# Education: Certificate
#
#
# Resume 3 Details:
# Category: Acted as the lead Application Analyst for LSU Medical Science
# Skills: System Software:
# Education: Bachelor of Science
#
#
# Resume 4 Details:
# Category: and 2018
# Skills: Deep expertise in designing,developing,
# Education: None
#
#
# Resume 5 Details:
# Category: Core Qualifications
# Skills: None
# Education: Masters of Science
#
#
# Resume 6 Details:
# Category: Additional Information
# Skills: Team mediation, Budget Management, Delegation expert with a focus on results and team growth
# Education: 2009
#
#
# Resume 7 Details:
# Category: None
# Skills: -Great Organizational skills
# Education: Ph.D.
#
#
# Resume 8 Details:
# Category: Led 3 Summer Camp Programs, and student teach in 3 schools at the Portland District
# Skills: None
# Education: Program Workforce (Rota High School, M.P., 96951, Songsong Village, CNMI) Teacher Aide for High School students
#
#
# Resume 9 Details:
# Category: Molecular Biology
# Skills: banking, Chemistry, customer support, DNA, GC, government, marketing, materials, Network, reporting, Research, sales, Teaching, Trainer,
# Education: None
#
#
# Resume 10 Details:
# Category: Identification of Nematodes for Professional Consultants Green house training course.
# Skills: None
# Education: Master of Science
#
#
# Resume 11 Details:
# Category: presentations and MS Excel for data manipulation (ex. pivot tables, charts, etc.) *Basic experience in SPSS, Bloomberg, and QuickBooks
# Skills: accounting, Basic, Bloomberg, C, charts, Credit, credit risk, documentation, senior management, financial, Analyze financial statements, financial
# Education: May 2010
#
#
# Resume 12 Details:
# Category: Self-motivated professional
# Skills: Â
# Education: High School Diploma
#
#
# Resume 13 Details:
# Category: Led the pre-formulation and formulation development of a topical cream and gel for psoriases which successfully entered clinical trials.
# Skills: None
# Education: 2014
#
#
# Resume 14 Details:
# Category: High School Diploma
# Skills: TAAMs, ArcGIS 10.5.1, Trimble Unit, Garmin, ATV, Personal Computer - Microsoft Excel, PowerPoint, Microsoft Word, Write and Read
# Education: 2004
#
#
# Resume 15 Details:
# Category: Â  Team workÂ
# Skills: Production and Processing
# Education: None
#
#
# Resume 16 Details:
# Category: Microsoft Word documents, Excel spreadsheets and Power Point presentations Experienced in ARC10 Geographic Information Systems
# Skills: Microsoft Word documents, Excel spreadsheets and Power Point presentations Experienced in ARC10 Geographic Information Systems
# Education: None
#
#
# Resume 17 Details:
# Category: None
# Skills: Physical Planning and Land Management
# Education: Bachelor of Science
#
#
# Resume 18 Details:
# Category: Advisor: Michael Harnett, GCC Scholars Program Director
# Skills: Microsoft Word, Excel, PowerPoint, Office, Outlook, R-Studio
# Education: Master of Science & Philosophy
#
#
# Resume 19 Details:
# Category: Green house training course.
# Skills: Data collection, Maintain inventory, Statistical Analysis, Prepare samples
# Education: Master of Science
#
#
# Resume 20 Details:
# Category: None
# Skills: A proven professional, experienced in sales, marketing, management, and business development. Public and Private Sector
# Education: Masters in Business Administration
#
#
# Resume 21 Details:
# Category: major donor development Effectively influences others Hardworking Professional Summary Education and Training
# Skills: accounting, Business Intelligence 4.0, Business law, hardware, customer satisfaction, customer services, data entry, databases, Database,
# Education: Public Health (Mental Health)
#
#
# Resume 22 Details:
# Category: None
# Skills: None
# Education: December 2015
#
#
# Resume 23 Details:
# Category: Implemented new work process flow which increased department productivity.
# Skills: Data Entry, Printers, Clients, Loans, Tax Returns, Clerk, Multiline, Maintenance, Recruiting, Recruitment, Testing, Games, Instructor, Teaching,
# Education: Wayne State University
#
#
# Resume 24 Details:
# Category: None
# ...
# Education: MBA
#
#
# Resume 6 Details:
# Category: None
# Skills: Microsoft office with modern classroom technology
# Education: Masters of Arts
#
#
# Resume 7 Details:
# Category: None
# Skills: Instructional Design, Teaching, Progress Monitoring, Course
# Education: M. Ed
#
#
# Resume 8 Details:
# Category: long-term relationships with customers.
# Skills: agency, budgeting, budgets, business strategy, closing, cold calling, interpersonal, communication skills, Excellent Communication, oral, contracts,
# Education: None
#
#
# Resume 9 Details:
# Category: None
# Skills: National Board Certified
# Education: M.Ed
#
#
# Resume 10 Details:
# Category: Summary
# Skills: Training
# Education: Created job shadows and internships with local businesses
#
#
# Resume 11 Details:
# Category: 13, Coney Island Generation Gap, and Urban Neighborhood Services.
# Skills: Classroom Management
# Education: Master of Education
#
#
# Resume 12 Details:
# Category: Housekeeping
# Skills: People skills
# Education: Associate of Science
#
#
# Resume 13 Details:
# Category: None
# Skills: Microsoft Office, Microsoft Windows XP Professional (Word, Excel, PowerPoint, Publisher), Internet Browsers, Learning Google Chrome &
# Education: 2003
#
#
# Resume 14 Details:
# Category: medical issues
# Skills: acute care, art, Autism, basic, biochemistry, biology, Chemistry, CPR, focus, fundraising, Law, patient care, pediatrics, physical therapy,
# Education: None
#
#
# Resume 15 Details:
# Category: None
# Skills: Purposeful lesson planning
# Education: endorsement
#
#
# Resume 16 Details:
# Category: TEACHER
# Skills: discharge planning, lesson plans, evaluate patients, supervision
# Education: None
#
#
# Resume 17 Details:
# Category: None
# Skills: academic, Arts, Coach, continuous improvement, Council, critical thinking, educational programs, English, instruction, Leadership, leadership
# Education: December 2014
#
#
# Resume 18 Details:
# Category: Recognized for work ethics, great customer service skills, and involvement as a team player
# Skills: Accounting, Credit, Invoices, Budget, Accounts Payable, Cash, Of Accounts, Accountant, Audits, Billing, Buying/procurement, Customer
# Education: Bachelors of Arts
#
#
# Resume 19 Details:
# Category: Coached Hunter Forward, Kristen Markoe, CUNYAC Player of the Year
# Skills: Games, Increase, Recruitment, Associate, Budget, Fundraising, Health And Wellness, Liaison, Recruiting, Arrangements, Exchange, Progress,
# Education: Skidmore College
#
#
# Resume 20 Details:
# Category: Co-teaching experience in kindergarten
# Skills: Microsoft Office
# Education: 2015
#
#
# Resume 21 Details:
# Category: Elected member of School Site CouncilÂ
# Skills: None
# Education: Plans.
#
#
# Resume 22 Details:
# Category: *Hands on Math Instruction
# Skills: *Classroom management
# Education: The University of Texas
#
#
# Resume 23 Details:
# Category: programs to bring in more families and revenue to my school.
# Skills: bookkeeper, Child Care, conferences, counseling, documentation, Educator, email, Human Resources, Internet navigation, meetings, mentor,
# Education: May 1999
#
#
# Resume 24 Details:
# Category: None
# Skills: Filing and data archiving,Â
# Education: Bachelor of Science
#
#
# Resume 25 Details:
# Category: Strong interpersonal skills
# Skills: bookkeeping, conferences, email, English 3, English 4, instruction, lesson plans, materials, meetings, mail, money, office, notary public, payroll,
# Education: December 2011
#
#
# Resume 26 Details:
# Category: None
# Skills: Classroom management
# Education: BS
#
#
# Resume 27 Details:
# Category: excellent work ethic
# Skills: Current Virginia
# Education: None
#
#
# Resume 28 Details:
# Category: None
# Skills: Assessments
# Education: Curriculum and Instruction Licensure
#
#
# Resume 29 Details:
# Category: Proficienct
# Skills: academic, consultation, Educator, English, functional, instruction, materials, progress, reading, speech therapy, Teacher, technical support, vision
# Education: Master of Science degree
#
#
# Resume 30 Details:
# Category: experiences.
# Skills: Academic planning, administrative skills, case management, clerical,Â  documentation and shorthand, research,Â  lesson planning, newsletter
# Education: 2009
#
#
# Resume 31 Details:
# Category: Solved severe child behavioral issues in positive and constructive ways.
# Skills: None
# Education: 2013
#
#
# Resume 32 Details:
# Category: theatrical play, musical instruments and hands-on learning.Â
# Skills: cash handling, cost control, critical thinking, financial accounting, inventory levels, lesson planning, personnel, positioning, quality, receiving,
# Education: 2013
#
#
# Resume 33 Details:
# Category: Intimate knowledge of school system
# Skills: Meticulous attention to detail
# Education: None
#
#
# Resume 34 Details:
# Category: First Aid, CPR, and CPI Certified.
# Skills: Positive reinforcement methods
# Education: None
#
#
# Resume 35 Details:
# Category: Scott Main Exchange supervisor of the month 5 times.
# Skills: Leadership, Motivation, Management, Speaking, Listening, Counseling, Teaching, Computer Literacy, Training, Editing, Organizing, Development,
# Education: Master of Science
#
#
# Resume 36 Details:
# Category: Highly organized
# Skills: CPR
# Education: Infant, toddler and preschool curricula
#
#
# Resume 37 Details:
# Category: Enjoys using modern technology in the classroom.
# Skills: Increase, Training, Coaching, Teaching, Clerical, Filing, Class, Comprehensive Large Array Data Stewardship System, Liaison, Translate,
# Education: Bakersfield College
#
#
# Resume 38 Details:
# Category: Reliable
# Skills: arts, conferences, edit, facsimile, instruction, Leadership skills, notes, materials, meetings, Access, Excel, Microsoft Office, Outlook, PowerPoint,
# Education: M.Ed
#
#
# Resume 39 Details:
# Category: reach solutions.
# Skills: Results-oriented
# Education: Bachelor of Arts
#
#
# Resume 40 Details:
# Category: Administrative management
# Skills: None
# Education:
#
#
# Resume 41 Details:
# Category: Summary
# Skills: Accounting, approach, attention to detail, back-up, cash handling, cash register, cashier, closing, coaching, communication skills, Conflict
# Education: Associates
#
#
# Resume 42 Details:
# Category: Compliance / Policies / Procedures
# Skills: Creative Lesson Planning
# Education: Bachelor of Arts
#
#
# Resume 43 Details:
# Category: Awarded multiple Letters of Appreciation for being a community pillar for Marine Corps Security Force Battalion, Bangor, WA.
# Skills: None
# Education: Leading Enlisted Member and Field Training Officer
#
#
# Resume 44 Details:
# Category: None
# Skills: MS Office proficient
# Education: Associate of Applied Science
#
#
# Resume 45 Details:
# Category: None
# Skills: academic, Photoshop, advertising, cancer, competitive, conferences, consultant, content, creative design, Creative Problem Solving, Client
# Education: M.D
#
#
# Resume 46 Details:
# Category: Received a Certificate of Completion at Los Angeles Southwest College.
# Skills: Child care, Family servicing, conferences, first aid, instructing, lesson plans, directing, meetings, Mental Health, management information system,
# Education: Child Development Site Supervisor's Permit.
#
#
# Resume 47 Details:
# Category: Creative and Positive
# Skills: Detailed and Accurate Transcription Abilities
# Education: 1990
#
#
# Resume 48 Details:
# Category: Industrial University of Santander. Colombia. TH: 120 hours. (2006).
# Skills: MicrobiologÃ​a, Director General, Directora, Industrial, Jefe De Laboratorio, Acta, Bpm, Bpm (business Process Management), C, Carne De
# Education: High School Diploma
#
#
# Resume 49 Details:
# Category: Eighth grade semi-formal coordinator
# Skills: Strong interpersonal skills
# Education: Accomplishments
#
#
# Resume 50 Details:
# Category: None
# Skills: Accounts Payable, Advertising, Bookkeeping, Budgets, Charts, Customer Service, Financial Reporting, Payroll, Spreadsheets
# Education: 2007
#
#
# Resume 51 Details:
# Category: HISTORY TEACHER
# Skills: None
# Education: Ph.D.
#
#
# Resume 52 Details:
# Category: None
# Skills: administrative, arts, Â basic, Coach, Customer service, Â Inspect, instruction, inventory, laundry, transport materials, Â meal prep, personnel,
# Education: None
#
#
# Resume 53 Details:
# Category: Excellent classroom management
# Skills: accounting, accounts payables, Administrative, AOL, auditing, banking, benefits, Budget, Business Works, content, counseling, clients, customer
# Education: None
#
#
# Resume 54 Details:
# Category: Autodesk Revit
# Skills: Operating systems: Windows 7/XP/2000, Android, and MS-DOS *Software: Autodesk Civil 3D, Autodesk AutoCAD, Autodesk Inventor
# Education: Master of Education
#
#
# Resume 55 Details:
# Category: Microsoft word, Microsoft Works, Excel, Internet Research, Powerpoint.
# Skills: Accounts Receivable,
# Education: 2010
#
#
# Resume 56 Details:
# Category: Received award for customer service recognition and ability to work well with the other team members.
# Skills: Excellent
# Education: None
#
#
# Resume 57 Details:
# Category: students.
# Skills: academic, budget, coaching, conferences, Curriculum development, educator, instruction, Lesson planning, lesson plans, Math, Access,
# Education: None
#
#
# Resume 58 Details:
# Category: Teaching, tutoring and counseling
# Skills: bilingual speaking and reading fluently in English and Spanish, demonstrate your ability to work well with a team, handles details; coordinates and
# Education: None
#
#
# Resume 59 Details:
# Category: None
# Skills: Work History
# Education: Masters
#
#
# Resume 60 Details:
# Category: growth mindset to develop young minds and inspire love of learning.
# Skills: Behavior modeling
# Education:
#
#
# Resume 61 Details:
# Category: None
# Skills: Â Counselor, academic, native Spanish speaker, Leadership, Workshops, goal setting and implementation, effectively work with parents, time
# Education: Counseling Certification
#
#
# Resume 62 Details:
# Category: Flexible and adaptable
# Skills: None
# Education: Bachelor of Science
#
#
# Resume 63 Details:
# Category: Flexible and adaptive
# Skills: Team player and effective collaborator
# Education: Master of Education
#
#
# Resume 64 Details:
# Category: None
# Skills: E
# Education: University of Redlands
#
#
# Resume 65 Details:
# Category: IEP familiarity
# Skills: None
# Education: Masters of Science
#
#
# Resume 66 Details:
# Category: Highlights
# Skills: None
# Education: 12/2009
#
#
# Resume 67 Details:
# Category: None
# Skills: MS Office
# Education: Bachelor of Arts
#
#
# Resume 68 Details:
# Category: to explain complicated concepts in an easily understandable manner.
# Skills: None
# Education:
#
#
# Resume 69 Details:
# Category: collegiate athlete
# Skills: administrative support, scheduling appointments, approach, Arts I, attention to detail, billing, communication skills, customer service, dependable,
# Education: Bachelor of Applied Science
#
#
# Resume 70 Details:
# Category: None
# Skills: None
# Education: Associate of Arts
#
#
# Resume 71 Details:
# Category: None
# Skills: None
# Education: 1999
#
#
# Resume 72 Details:
# Category: Accurate and detailed
# Skills: organizational skills
# Education: Bachelor of Arts
#
#
# Resume 73 Details:
# Category: Liberal Arts
# Skills: Creative at lesson planning and hands-on instruction.
# Education: Bachelor of Arts
#
#
# Resume 74 Details:
# Category: .
# Skills: academic, art, interpersonal skills, instruction, lesson plans, notes, materials, meetings, PowerPoint, camera, progress, teaching, training programs,
# Education: Bachelor of Science
#
#
# Resume 75 Details:
# Category: Complex problem solver
# Skills: None
# Education: Masters in Education
#
#
# Resume 76 Details:
# Category: competent with standard office equipment & procedures, and excellent interpersonal communication skills-verbal and written.
# Skills: None
# Education: None
#
#
# Resume 77 Details:
# Category: None
# Skills: instruction, inventory, Market, pricing, purchasing, Teacher, Advanced Floral Designer, Entrepenuer
# Education: Mixology
#
#
# Resume 78 Details:
# Category: PeopleSoft
# Skills: Adobe Photoshop, Adobe Premier, Benefits, communication skills, conferences, Curriculum Development, Flash, Human Resource, instruction,
# Education: Walden University Diploma
#
#
# Resume 79 Details:
# Category: Docs, Â Dropbox, Excel
# Skills: Average computer literate
# Education: Effectively work with parents
#
#
# Resume 80 Details:
# Category: Security understanding
# Skills: Behavior modeling
# Education: None
#
#
# Resume 81 Details:
# Category: Consistently received positive feedback from parents.
# Skills: CPR certified
# Education: Infant, toddler and preschool curricula
#
#
# Resume 82 Details:
# Category: Exceptional attention to detail
# Skills: None
# Education: Graduate Teaching Licensure
#
#
# Resume 83 Details:
# Category: None
# Skills: Strong communication skills
# Education: Chattahoochee Technical College
#
#
# Resume 84 Details:
# Category: SUBSTITUTE TEACHER
# Skills: Ten key, basic, conferences, customer service, delivery, direction, educational programs, keyboard, leadership, market, presentations, problem
# Education: Oregon State University
#
#
# Resume 85 Details:
# Category: None
# Skills: Word, Excel, and PowerPoint Ã¢â‚¬Â¢Advanced knowledge and skills in using media tools for teaching purposes such as
# Education: Master of Arts
#
#
# Resume 86 Details:
# Category: Opened before and after school chess fun tables for learning/practicing
# Skills: None
# Education: Ph.D
#
#
# Resume 87 Details:
# Category: Computer literate, drivers, listening, natural, packaging, quality, rapport, teaching
# Skills: Computer literate, drivers, listening, natural, packaging, quality, rapport, teaching
# Education: None
#
#
# Resume 88 Details:
# Category: Managing, meetings, office, problem solving, processes, progress, Teacher, Teaching, time management, written
# Skills: charts, Excellent communication, conferences, Conflict resolution, Critical thinking, focus, instruction, instructional design, Lesson planning,
# Education:
#
#
# Resume 89 Details:
# Category: Outlook, QuickBooks, Internet research
# Skills: Administrative, administrative support, budgets, communication skills, Excellent communication, contracts, database, financial reports, grants,
# Education: Master of Science
#
#
# Resume 90 Details:
# Category: hard worker, reliable, honest, diligent, thorough, collaborative and approachable.
# Skills: arbitration, communication skills, CPI, creative problem solver, customer services, insurance, law enforcement, Team Lead, logistics, Director,
# Education: Bachelor of Science
#
#
# Resume 91 Details:
# Category: Developed innovative classroom management tools, which were implemented on a large scale for the teachers among the school.
# Skills: Bi-lingual Farsi and English
# Education: Bachelor of Arts
#
#
# Resume 92 Details:
# Category: CPR/BLS certified
# Skills: â€¢ Well versed with the standards of hygiene and sanitationâ€¢ Demonstrated ability to perform duties in a busy environment
# Education: None
#
#
# Resume 93 Details:
# Category: GPA-3.45
# Skills: Time Management
# Education: Company Name
#
#
# Resume 94 Details:
# Category: None
# Skills: Conducted Peer Council with Youth
# Education: Associate of Arts
#
#
# Resume 95 Details:
# Category: district.
# Skills: None
# Education: University of Central Missouri
#
#
# Resume 96 Details:
# Category: Summary
# Skills: arts, content, Content Development & Management, content creation, Curriculum Development, databases, Dimensions, Event Planning &
# Education: and Science Education and Public Outreach Forums.
#
#
# Resume 97 Details:
# Category: excellent client service.
# Skills: Â·Â Â Â Â Â Â Â Â  Computer literate and valid Texas driver's license/insurance
# Education: Dallas Theological Seminary-Houston Campus
#
#
# Resume 98 Details:
# Category: Rookie Teacher of the Year, Greco Middle School 2002-2003
# Skills: Highly Effective TeacherÂ
# Education: University of South Florida
#
#
# Resume 99 Details:
# Category: None
# Skills: [Number]
# Education: Bachelor of Science
#
#
# Resume 100 Details:
# Category: Â plans focused on age and level-appropriate material.
# Skills: conflict resolution, course development, critical thinking, curriculum development, Â instructional design, Â research, staff development, teaching,
# Education: University of Phoenix,
#
#
# Resume 101 Details:
# Category: Calm and patient
# Skills: None
# Education: Conflict resolution techniques
#
#
# Resume 102 Details:
# Category: Communication and problem solving skills.
# Skills: Superb communication both verbal and written.
# Education: None

# %%
# !pip install datasets
from datasets import load_dataset
# Out:
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: datasets in c:\users\lenovo\anaconda3\lib\site-packages (2.14.5)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (1.24.3)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (11.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (3.3.0)
# Requirement already satisfied: multiprocess in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (2023.3.0)
# Requirement already satisfied: aiohttp in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (3.8.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (0.17.1)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.12.0)

# %%
# Load the job descriptions dataset
job_descriptions_dataset = load_dataset('jacob-hugging-face/job-descriptions')

# %%
# Display 10-15 job descriptions
sample_job_descriptions = job_descriptions_dataset['train']['job_description'][:15]
for idx, job_description in enumerate(sample_job_descriptions, start=1):
    print(f"Job Description {idx}:\n{job_description}\n")
# Out:
# Job Description 1:
# minimum qualifications
# bachelors degree or equivalent practical experience years of experience in saas or productivity tools businessexperience managing enterprise accounts with sales cycles
# preferred qualifications
#  years of experience building strategic business partnerships with enterprise customersability to work through and with a reseller ecosystem to scale the businessability to plan pitch and execute a territory business strategyability to build relationships and to deliver results in a crossfunctionalmatrixed environmentability to identify crosspromoting and uppromoting opportunities within the existing account baseexcellent account management writtenverbal communication strategic and analyticalthinking skills
# about the job
# as a member of the google cloud team you inspire leading companies schools and government agencies to work smarter with google tools like google workspace search and chrome you advocate the innovative power of our products to make organizations more productive collaborative and mobile your guiding light is doing whats right for the customer you will meet customers exactly where they are at and provide them the best solutions for innovation using your passion for google products you help spread the magic of google to organizations around the world
# the google workspace team helps customers transform and evolve their business through the use of googles productivity collaboration and content management suite of applications as part of an entrepreneurial team in this growing business you will help shape the future of businesses use technology to connect with customers employees and partners
# as a google workspace sales specialist you will be responsible for maintenance and expansion of google workspace business growth across the region with customers in this role youll create and execute the strategy and provide unique insights on applying google workspace solutions to enterprisesyou will build an excellent pipeline and work with the account teams to build out the customer solution and establish partnerships you will strategize with partners to increase account and territory business growth you will work directly with customers coordinate internal resources and construct successful strategies at account and territory level
# google cloud accelerates organizations ability to digitally transform their business with the best infrastructure platform industry solutions and expertise we deliver enterprisegrade solutions that leverage googles cuttingedge technology  all on the cleanest cloud in the industry customers in more than  countries and territories turn to google cloud as their trusted partner to enable growth and solve their most critical business problems
#
# Job Description 2:
# description
# as an asc you will be highly influential in growing mind and market share of apple products while building longterm relationships with those who share your passion
# customer experiences are driven through you and your partner team growing in an ever changing and challenging environment you strive for perfection whether its maintaining visual merchandising or helping to grow and develop your partner team
#
# qualifications
# a passion to help people understand how apple products can enrich their livesexcellent communication skills allowing you to be as comfortable in front of a small group as you are speaking with individuals years preferred working in a dynamic sales andor results driven environment as well as proven success developing customer loyaltyability to encourage a partner team and grow apple business
#
# Job Description 3:
# its an amazing time to be joining netflix as we continue to transform entertainment globally netflix is the worlds leading internet entertainment service with over  million paid memberships in over  countries enjoying tv series documentaries and feature films across a wide variety of genres and languages members can watch as much as they want anytime anywhere on any internetconnected screen members can play pause and resume watching all without commercials or commitments
#
# the consumer products team aspires to connect members to our content and each other by bringing their favorite stories to real life our products and campaigns should entertain delight and bring joy to our fans all over the world
#
# due to the expansion of licensees and categories we are in need of additional support with active and prospective partnerships for current and upcoming titles we are looking for a licensing coordinator who will work across the entire slate of netflix content to bring our content to life via compelling products they will support two managers who oversee the food and beverage toys and collectibles electronics and sporting goods categories focusing on us and canada regional opportunities the individual would be a taskmaster extraordinaire who will assist in the day to day deliverables working alongside internal as well as external partners the successful candidate will be a dynamic professional who has an understanding of the outbound licensing workflow and can roll up their sleeves to knock out tasks in an orderly and swift pace
#
# key responsibilities
# help drive business by supporting licensing managers on tasks related to category management facilitating information between external and internal stakeholders and maintaining communication of product and partner planscoordinate with internal teams to gather and distribute brand and marketing updates to share out with licensing partnersmaintain and update title strategies with category licensing plans and activitycollaborate with licensing partners to obtain placement updates and distribute to internal business partnersassist licensing managers with compiling licensing recaps following product launches schedule meetings and when needed draft and distribute meeting recaps to respective business partnersprepare distribute and track deal memos and final agreements to ensure deals are processed efficiently through all stepswork with licensing managers to prepare onboarding for new licenseesfacilitate receipt of forecasts and send royalty payment reminders as neededpartner with creative teams to keep product development on track to attain commercial objectives
# what we need from you
# demonstrated  years of experience in preferably outbound licensing functionunderstanding of category manufacturing and sales cycle for toys andor food and beverage is preferredexperience working with reputable entertainment andor lifestyle brandsselfstarter motivated proactive and flexibleability to thrive under pressure in a fastpaced dynamic environmentpossess attention to details with superb organizational skillsmultitasker extraordinaire with ability to prioritizeexcellent communicator alignment with our company culture and values
#
# Job Description 4:
# description
#
# web designers looking to expand your professional reach welcome to robert half marketing  creative start the process with robert half today
#
# we are searching for highly skilled web designers with experience working within corporate brand standards and guidelines the ideal candidates would have advanced skills in creating wireframes designing mobile applications landing pages interactive sites qa testing experience working with various interfaces and familiarity with uxui design principles candidates are expected to have strong skills in adobe photoshop illustrator and indesign any experience in html css and javascript is a major plus familiarity with content management systems is highly preferred
#
# there is nothing more satisfying when looking for freelance and fulltime creative opportunities than working with someone who knows your area of expertise as industry professionals robert half marketing  creative is a team that puts your needs first and effectively represents you as a creative talent thats the kind of service youll receive from our team at robert half
#
# we have marketing advertising and creative backgrounds just like yours  so were on your side right from the start could you ask for a better support team
#
# requirements
#   years experience in a web design role
#  experience working within a clients brand standards or guidelines
#  advanced skill in the adobe creative cloud
#
# innovation starts with people
#
# robert half is the worlds first and largest specialized talent solutions firm that connects highly qualified job seekers to opportunities at great companies we offer contract temporary and permanent placement solutions for finance and accounting technology marketing and creative legal and administrative and customer support roles
#
# robert half puts you in the best position to succeed by advocating on your behalf and promoting you to employers we provide access to top jobs competitive compensation and benefits and free online training stay on top of every opportunity  even on the go
#
# questions call your local office at  robert half will consider qualified applicants with criminal histories in a manner consistent with the requirements of the san francisco fair chance ordinance all applicants applying for us job openings must be legally authorized to work in the united states benefits are available to temporary professionals visit
#
#   robert half an equal opportunity employer mfdisabilityveterans by clicking apply now youre agreeing to
#
# Job Description 5:
# at trackfive weve got big goals were on a mission to revolutionize recruiting with easytouse tools and platforms and we envision a future where we can fill every open job with a qualified candidate thats why were looking for pioneerspeople who blaze trails and are committed to doing great work we might be small but we are mightyweve got more than a decade of skin in the game yet weve managed to maintain our startup feel the trackfive culture is centered around hard work but we believe strongly in balance and having funin a nutshell we love coming to work we value different backgrounds and perspectives believing that together we can use our creativity and curiosity to make amazing things happen
#
# if youre ready to be a part of something exciting trackfive is currently searching for a talented web developer this position is not dependent on location and can be local to the office with hybrid or inoffice options available or fully remote
#  please note that a skills test may be a requirement for potential candidates in the interview process
#
# what youll do
#
# the web developer is responsible for delivering robust solutions to our clients they work collaboratively to support trackfives existing web application portfolio and the successful delivery of new development initiatives
#
# the life of a trackfive web developer
#  contribute to all phases of the development lifecycle by following internal procedures and coding standards
#  build  layouts from provided psd files
#  build dynamic web apps using phpmysqlframeworks
#  leverage rest services and other thirdparty apis
#  rapidly solve problems bugs and compatibility issues
#  troubleshoot test and maintain the core product software and databases to ensure strong optimization and functionality
#  develop and deploy new features to facilitate related procedures and tools as necessary
#
# skills necessary
#   years or experience with html and csssass
#   years of experience with programming php applications and lamp stack development
#  experience with   javascript and jquery
#  thorough understanding of relational databases and security relating to phpmysql
#  expert knowledge with content management systems either from your own design or from mvc frameworks such as zend laravel etc
#  ability to build and consume custom soap and rest apis
#   years of experience writing unit testsdetailing procedures
#  selfmotivated requiring minimal supervision
#  exceptional organization and communication skills
#
# why you want to work at trackfive
#  free health insurance for employees with no waiting period
#  dental and vision insurance trackfive splits the cost with you
#  your birthday is a paid holiday
#  companypaid short and longterm disability insurance
#  companypaid life insurance
#  flex time
#  paid parental leave
#  companymatched retirement plan with no waiting or vesting period
#  the opportunity to workfromhome a few days a week
#  so much swag
#  cool inoffice perks like free snacks massages yoga and bringyourpettowork days just to name a few
#  the opportunity to work with a great group of people up to some very exciting things
#  the opportunity to attend our epic annual holiday party
#  trackfive is an equal opportunity employer
#
# Job Description 6:
# designups is a nashville based design and interactive agency at designups we have a strong focus on elevating brands with our expertise in design and customer experience
#
# are you a frontend developer with a serious interest in design and ui this could be a great fit if so this job is for someone in the greater nashville area the majority of the work can be done remotely but we do require some time in our east nashville office location hey its not too bad to walk to five points pizza or wildcow for lunch
#
# this is a contract position to start with a competitive hourly rate we would like to find the right person to join our team for a longterm role
#
# skills needed
# strong attention to design details typography ui etc
# translating designs responsively for multiple screen sizes
# familiarity with bootstrap or other similar frameworks
# wordpress knowledge and desire to learn is a major bonus
#
# Job Description 7:
# about the position
#
# the web designer is responsible for providing designrelated support for clientrelated and internal projects
#
# additionally the web designer is responsible for providing designrelated support for projects that are currently in development client review and postlaunch when assigned
#
# daytoday
#  collaborate closely with design managers on websiterelated projects including finishing projects that have a set art direction to hand over to the development team
#  work crossfunctionally with content and development teams which includes facilitating design discussions and adjusting existing designswebsites based on client feedback in preparation for the launch of their sites
#  partner with development teams to ensure the implementation of your designs and user experiences are of the highest quality
#  use and evolve our design systemlibrary to craft sketches flows prototypes and highfidelity visuals for client websites and product features
#  work closely with design leadership to inform and improve our processes identifying opportunities for elevating our product and user experience
#  provide designrelated support for postlaunch projects
#
# requirements
#
# our ideal candidate
#  is detailoriented has an excellent eye for detail and enjoys delivering pixelperfect and welldocumented designs
#  knows how to design websites has experience working with and understanding responsive design patterns and systems
#  is prepared to take the baton and run gladly takes on projects with set art direction and finishes off remaining design production work
#  has design system experience has experience working with scalable design systems within an inhouse design team
#  is a team contributor more than willing to work with design managers to develop the strategy and rationale for features and improvements to internal processes
#  can speak up and be understood has strong verbal and written communication skills which is a must for a remote company
#  can adjust and pivot can navigate and move forward quickly within a fastscaling company and an everevolving creator website tool
#  is hungry to improve gladly welcome feedback on their own performance from design managers along with nondesigners with the intent of professional growth in the company
#  most importantly can joke around a sense of humor is a must in our company
#
# our company culture revolves around among other things working hard and laughing harder
#
# requirements
#   years of experience as an individual contributor on a web or product design team for desktop and mobile
#  an excellent portfolio showcasing a strong foundation in typography interaction and visual design and ideation
#
# bonus props for personal projects that display your design aesthetic and passions
#  solid understanding of building usable accessible ada and modular design systems that can scale
#
# bonus props for certification in or related to ada
#  experience facilitating the adoption of visual design andor patterns across a design project
#  excellent understanding of figma and other design tools
#  excellent written and verbal communication skills and ability to clearly communicate design decisions
#  strong organizational skills and a selfstarter
#
# benefits
#  remote always
#  generous pto
#  allowance for continuing education or training
#  shiny new gear of your choice apple products
#  medical dental longterm and short term disability insurance
#  companysponsored life insurance
#
# dont meet  of the qualifications above thats okay apply anyway
#
# Job Description 8:
# job description
#
# zander insurance group is one of the largest direct marketers of insurance and identity theft solutions services in america our company was founded more than  years ago with the mission to protect families today millions of visitors browse our websites they are a vital way we acquire communicate with and keep our clients
#
# the web designer will drive revenue growth through the design and optimization of all clientfacing zander web properties
#
# the ideal candidate is comfortable working with highlevel stakeholders and they understand the importance of getting projects done efficiently most importantly the web designer enjoys working and as a result has a positive attitude that contributes to the overall health of the zander culture we are seeking a contributor who thrives while working autonomously asks questions when necessary and problem solves daily
#
# this is a fulltime position and includes a competitive salary and comprehensive benefits this position reports directly to the evp of marketing and will be based in our nashville tennessee office with opportunities to work remotely
#
# responsibilities include
#  designing compelling direct response websites and digital content that supports the zander brand campaign objectives and drives measurable actions
#  utilizing knowledge of zander products and services to create designs that support an action or campaign goal
#  creating designs that are compatible across multiple devices and screen sizes
#  creating mockups to conceptualize designs and presenting ideas to stakeholders
#  continually improving the existing user experiences and in the process driving revenue growth
#  preproduction image optimization and preparation
#  work with key stakeholders to ensure appropriate review and approvals for all clientfacing sites
#
# the ideal candidate
#   years of digital design experience driving online sales or marketing
#  has the ability to communicate effectively with highlevel clients
#  thrives in a fastpaced and teamoriented environment
#  is open to new ideas and able to adapt to changes quickly
#   years of experience with
#  adobe creative suite including photoshop illustrator and indesign
#  sketch
#  has solid experience with ui wireframing
#  has a strong ability to articulate the why when presenting design concepts
#  htmlcss and js experience preferred but not required
#
# what we have to offer
#  potential to work from home
#  monthly profits distributions
#  health and dental insurance paid  by zander insurance
#   dollarfordollar matching on your k
#  generous paid time off
#
# we are an equal opportunity employer applicants are considered for position and are evaluated without regard to mental or physical disability race religion sexual orientation color gender national origin age marital status military or veteran status or any other protected local state or federal status unrelated to the performance of the work involved
#
# Job Description 9:
# tuff is a growth marketing team working with clients to drive growth by creating managing measuring and optimizing highperforming user acquisition campaigns were a fully remote and small team with endless opportunities for autonomy ownership and impact
#
# we work with clients in nearly every industry and a typical engagement with tuff includes paid search social ads seo content strategy creative and cro every account has a dedicated growth marketing lead and is supported by various channel experts
#
# for this position we are looking for an experienced web designer to join our cro team you will be the third web designer joining the team  the cro team also includes a conversion rate optimization specialist and ux copywriter
#
# in this role you will work on designs in figma for existing website optimizations and landing page development across  different client accounts this could include testing out different ctas remediating the homepage or other core pages adding in new landing pages refining pricing pages updating user flows redesigning blogs and more
#
# requirements
#
# about you
#  you are a skilled web designer who has the flexibility and understanding to work on multiple established brands at once with quick mockup design turnarounds and have a strong understanding of how your designs will be translated in the web build process
#  you have  years of experience managing quickturnaround designdevelopment projects in various cms platforms webflow wordpress shopify contentful etc and landing page buildings unbounce and leadpages for startups and scaleups
#  you have strong project management skills setting up and adhering to detailed production timelines following up with team members to get what you need and organizing creative assets for developers
#  you have a clean aesthetic and a sharp eye for layout color and typography
#  youre a strategic thinker and understand how to design digital website experiences that are compelling you have a passion for brand building and can help push user experience forward across all digital touchpoints
#  youre curious and solutionoriented and enjoy finding new and innovative design solutions you can work independently but are keen to collaborate across disciplines with developers cro and ux copy to design fresh website experiences
#
# during month  youll
#  shadow tuffs cro team lead on three existing tuff clients to learn more about their individual brands and ongoing cro and web design needs
#  adopt our existing development and design process by working with our existing web designers lyn and arturo
#  learn how to guide and own website project priorities timelines scopes and costs within the tuff process using teamwork and slack
#  design at least one website optimization and landing page for  different clients
#
# during months    youll
#  work on various website designs ongoing monthly improvements for five tuff clients this includes testing out different ctas remediating the homepage or other core pages adding in new landing pages refining pricing pages updating user flows redesigning blogs and more
#  work with growth marketers and the cro team at tuff as well as content and creative to implement website designs and updates for clients
#  manage one to three developer contractorsfreelancers who will be responsible for implementing your designs on our clients sites
#  fully guide website project priorities timelines scopes and costs within the tuff process
#
# things can change quickly at tuff this breakdown isnt prescriptive but intended to give you a better sense of the role
#
# benefits
#
# about you
#  you have  years of experience as a web designer with a background working on sites for companies in various industries
#  you have experience working with a creative production team and a familiarity with creative production tools mainly figma and adobe suite
#  you have an inclusive handson collaboration style with proven experience clearly communicating timelines and deliverables
#  you have a learning mindset you are committed to getting better every day
#  you have a bias toward action and are both efficient and adaptable
#  you are a driver focused on making an impact on the organization and clients every day
#  you have demonstrated success testing and uncovering useful insights and sharing them in an engaging form that inspires people to take action
#
# benefits
#
# we are a passionate team of thirty distributed across the us
#
# youll work closely with the whole team in particular with elle creative strategist lyn web designer arturo web designer and kristin sr growth marketer coo to get up to speed on current clients and iterate on the cro and web design process at tuff
#
#  fully remote  work from anywhere you want
#
#  comprehensive health vision and dental coverage
#
#  k with matching
#
#  unlimited pto policy  and we encourage you to take it
#
#  parental leave   paid  weeks
#
#  home office or coworking space stipend
#
#  month internet reimbursement
#
#  continuing training stipend of  annually
#
#  wellness day every quarter
#
#  annual team retreats
#
# the starting salary range for this role is   we use a compensation formula that adjusts for experience
#
# applicants must be based in the us
#
# Job Description 10:
# type of requisition regular
#
# clearance level must be able to obtain none
#
# job family web design
#
# gdit has over  years of experience supporting the technology science and mission of the environmental protection agency gdit technologists scientists and innovators are experts in moving applications to the cloud modeling massive data sets in highperformance computing environments supporting innovative and bleeding edge technologies and scientific initiatives defending the cyber landscape and driving automation
#
# highlevel skills
#  htmlcssjavascript
#  drupal
#  section  compliance expertise pertaining to pdfs adobe acrobat pro videos interactive trainings websites and web applications jaws dragon zoomtext articulate
#  graphics design adobe photoshop illustrator after effects and lightroom
#
# specific tasks
#  designs and builds complex graphics page layouts and animation that suit web pages and enhance its layout to create visual appeal
#  creates an advanced detailed draft of the website outlining the various web pages according to client specifications and needs
#  provides thorough testing to ensure the website is userfriendly and interactive
#  provides thorough review of the final webpage design for the next level production
#  collaborates with other web professionals and provide guidance on the implementation of the website
#  stays current with the latest design software to improve in knowledge and skills and be able to create better design quality
#  provides guidance and leadership to lessexperienced web designer personnel
#
# desired qualifications
#
# babs or equivalent experience  years of experience
#
# additional job description
#
# covid vaccination gdit does not have a vaccination mandate applicable to all employees to protect the health and safety of its employees and to comply with customer requirements however gdit may require employees in certain positions to be fully vaccinated against covid vaccination requirements will depend on the status of the federal contractor mandate and customer site requirements
#
# we are gdit the people supporting some of the most complex government defense and intelligence projects across the country we deliver bringing the expertise needed to understand and advance critical missions we transform shifting the ways clients invest in integrate and innovate technology solutions we ensure today is safe and tomorrow is smarter we are there on the ground beside our clients in the lab and everywhere in between offering the technology transformations strategy and mission services needed to get the job done
#
# gdit is an equal opportunityaffirmative action employer all qualified applicants will receive consideration for employment without regard to race color religion sex sexual orientation gender identity national origin disability or veteran status or any other protected class
#
# covid vaccination gdit does not have a vaccination mandate applicable to all employees to protect the health and safety of its employees and to comply with customer requirements however gdit may require employees in certain positions to be fully vaccinated against covid vaccination requirements will depend on the status of the federal contractor mandate and customer site requirements
#
# we are gdit the people supporting some of the most complex government defense and intelligence projects across the country we deliver bringing the expertise needed to understand and advance critical missions we transform shifting the ways clients invest in integrate and innovate technology solutions we ensure today is safe and tomorrow is smarter we are there on the ground beside our clients in the lab and everywhere in between offering the technology transformations strategy and mission services needed to get the job done
#
# gdit is an equal opportunityaffirmative action employer all qualified applicants will receive consideration for employment without regard to race color religion sex sexual orientation gender identity national origin disability or veteran status or any other protected class
#
# Job Description 11:
# web developer
#
# job id
#
#  positions
#
# location ustnnashville
#
# posted date
#
# category digital business  digital operations
#
# level representative
#
# more information about this job
#
# overview
#
# leading country music company sony music nashville is looking for a technical highlymotivated rockstar web developer are you the professional who can help us make a direct impact on our artists sales and label success in the online world
#
# consider this rewarding position in our digital department if you
#
# have the ability to design across a broad range of artistic styles
#
# are capable of working concurrently on multiple projects in a fastpaced environment and stay on deadline
#
# sony music entertainment is a global recorded music company with a roster of current artists that includes a broad array of both local artists and international superstars as well as a vast catalog that comprises some of the most important recordings in history sony music entertainment is a wholly owned subsidiary of sony corporation of america
#
# all qualified applicants will receive consideration for employment without regard to race color religion sex national origin disability or protected veteran status
#
# responsibilities
#
# the web developer will use technical skills to develop and maintain the online assets for sony music nashvilles roster of artist this will include the creation of digital assets coding of online campaigns maintenance of company and label internet and intranet websites and the collection and evaluation of marketing response data
#
# design create and code promotional pages social skins email campaigns banner ads web interfaces and page layouts
#
# collaborate closely with frontend and backend developers throughout the entire development process
#
# maintain and update active company label websites images audio files press releases graphics
#
# troubleshoot creative and technical challenges
#
# analyze and make recommendations regarding traffic and activity on community properties
#
# continually research emerging digital technologies and services
#
# advise director of strategy on best use of new trends and knowledge that could positively impact artist roster
#
# complete other duties and responsibilities as assigned
#
# qualifications
#
# at least  years of experience in building and maintaining websites
#
# proficiency in writing code in one or more of these languages htmlcssjavascript and basic phpmysql
#
# proven experience building and maintaining webbased platforms experience with wordpress
#
# strong grounding in interaction design fundamentals and web best practices
#
# experience with the adobe creative suite
#
# experience with audio and video editing
#
# knowledge of api integration
#
# basic knowledge of crossbrowser testing and responsive web design
#
# experience with motion graphics a plus
#
# must possess an online portfolio with a range of sample work
#
# the ideal candidate will have
#
# capacity to rapidly design and develop web pages based on shifting calendars
#
# aptitude to find solutions to novel coding issues and the resourcefulness to troubleshoot issues independently
#
# ability to be a highperforming team player enthusiastic to work with colleagues from marketing through technology
#
# enjoy a challenging and creative atmosphere in the music industry employees work in the music row area of nashville tennessee and receive outstanding benefits including k match medicaldentallifedisability insurance
#
# your cover letter is your opportunity to convince us you are the perfect person for this job take note to identify any experiences related to the job requirements and the ideal candidate described above
#
# note if you have previously applied for a sony music entertainment job and wish to submit a different résumé or cover letter than the one you last used follow these steps
#  apply for this job online
#  click on update profile from there upload a new résumé or copy and paste a new cover letter be sure to click update profile at the bottom of the page when youre done
#
# we communicate with applicants by email if you dont receive an email confirming our receipt of your application please check your spam filter and add us to your allowed email list autoreplyicimscom and noreplysonymusiccom
#
# Job Description 12:
# snapshot is looking for a back end developer to join our organization and make an immediate impact and help us ensure we meet our core purpose with every project  we live to overdeliver inspirational solutions you may be the right person for us if you
#
# are upbeat  meaning that you come to snapshot with a positive attitude and desire to improve  each week
#
# own your work  from your first day you are the type of individual that takes ownership of your projects and goes above and beyond for all our clients
#
# enjoy a challenge our deliverables and service standards are always changing and new projects kick off daily you stay ahead of the curve and enjoy learning more about the industry to help educate our clients and stay in the know
#
# about us
#
# snapshot is a fullservice digital agency bridging the gap between highquality video production awardwinning website design and creative online marketing strategies we help our clients big and small showcase their companies and products to the world in a fresh engaging way
#
# we have a heavy consistent project load and we need someone ready to hit the ground running if youre looking for a company that will stretch your creative abilities and teaches you the entrepreneurial spirit you belong here our team is selfmotivated disciplined and all work effectively as part of a team
#
# compensation benefits
#
#  salaried position with pay depending upon experience
#
#  health insurance coverage
#
#  life insurance policy
#
#  shortterm  longterm disability insurance
#
#   paid holidays  days of vacation and week personal paid time off
#
#  retirement plan
#
#  and more
#
# description requirements
#
# the candidate will be someone that can code with confidence and create the amazing backend framework to deliver on our clients vision and expectations they will possess critical thinking skills to put to themselves in our clients shoes and troubleshoot issues independently
#
# responsibilities include
#
#  helping to create amazing wordpress websites that reflect our clients brand and objectives
#
#  execute updates and troubleshoot client websites for a wide variety of issues and resolutions
#
#  seamless integrations of hubspot functions and plugins
#
#  use of project management software for tracking projects updates and completion
#
#  timely completion of projects tracking progress in project management system
#
#  professional communication with team
#
# required experience
#
#  bachelors degree or equivalent experience
#
#   years professional experience
#
#  understanding of objectoriented programming and mvc
#
#  custom scripting and thirdparty api integration
#
#  experience using hubspot integrations
#
#  custom wordpress theming sage preferred
#
#  custom rest api development
#
#  expert level css foundation or bootstrap php  mysql
#
#  knowledge of responsive and mobilefirst best practices
#
#  strong ability to debug crossbrowser issues
#
#  detailoriented with strong organizational skills
#
#  selfmotivated disciplined and able to work effectively as part of a team
#
#  ability to maintain ownership of individual projects from start to finish while also working on collaborative projects
#
#  familiarity with illustrator photoshop and sketch
#
# bonus
#
#  experience with laravel
#
#  basic commandline experience
#
#  experience with deploying websites
#
#  experience with git or other version control systems
#
#  knowledge of css preprocessors such sass and less
#
# job type fulltime
#
# pay    per year
#
# benefits
#  k
#  k matching
#  dental insurance
#  employee assistance program
#  health insurance
#  health savings account
#  life insurance
#  paid time off
#  parental leave
#  retirement plan
#  vision insurance
#
# schedule
#   hour shift
#  monday to friday
#
# ability to commuterelocate
#  nashville tn  reliably commute or planning to relocate before starting work preferred
#
# education
#  bachelors required
#
# experience
#  backend development  year required
#
# work location one location
#
# Job Description 13:
#  we are seeking a senior ui designer who relishes in methodically applied color palettes and takes pride in your type of ramp
#  when your work is done the mobile apps and responsive websites you create not only look amazing but act as a seamless extension of your clients brand voice and business strategy
#  act as the lead or contributing designer on projects presenting work across the design ux and development teams
#  create designs that are onbrand for our clients and follow a projects creative vision and business strategy while putting the user first
#  collaborate with other groups like developers engagement managers and ux designers to deliver highquality creative for both internal and clientfacing projects
#  provide constructive art direction alongside your fellow designers
#  work on projects of varying length and complexity
#  contribute to improvements in our creative process and capabilities
#    years of related design experience
#  experience and ability to work in a variety of digitalfocused design applications like sketch invision and illustrator
#  proficiency in web optimization principles and other production methods
#  crossplatform web  mobile development experience ios android etc
#  proficiency in producing pixel perfect design files
#  ability to use motion tools like adobe after effects principle for mac and framer to communicate interaction design and motion
#  must be legally authorized to work in the united states without the need for employer sponsorship now or at any time in the future
#  experience creating design systems for enterpriselevel experiences
#  experience creating icons and other custom illustrations for experiences
#  curiosity to learn from others and a passion for learning and pursuing your craft
#  experience working in a consulting environment
#  participation in the wider design community and connections with creative organizations such as aiga creative mornings etc
#  ability to take feedback and use it to improve your work
#  a developed personal style with the ability to scale and adapt as the project needs
#  sits within our advertising marketing  commerce offering
#  within our group we create content communications and experiences that engage and inspire our clients customers to act
#  we implement and operate the technology platforms that enable personalized content commerce and usercentric experiences
#  and in doing so we transform our clients marketing and engagement operations into modern datadriven creatively focused organizations  all built to drive growth
#  from developing a stand out resume to putting your best foot forward in the interview we want you to feel prepared and confident as you explore opportunities at deloitte
#  check out recruiting tips from deloitte recruiters
#  at deloitte we know that great people make a great organization
#  we value our people and offer employees a broad range of benefits
#  learn more about what working at deloitte can mean for you
#  our people and culture
#  our diverse equitable and inclusive culture empowers our people to be who they are contribute their unique perspectives and make a difference individually and collectively
#  it enables us to leverage different ideas and perspectives and bring more creativity and innovation to help solve our client most complex challenges
#  this makes deloitte one of the most rewarding places to work
#  learn more about our inclusive culture
#  from entrylevel employees to senior leaders we believe theres always room to learn
#  we offer opportunities to build new skills take on leadership opportunities and connect and grow through mentorship
#  from onthejob learning experiences to formal development programs our professionals have a variety of opportunities to continue to grow throughout their career
#  as used in this posting deloitte means deloitte consulting llp a subsidiary of deloitte llp please see
#  deloittecomusabout for a detailed description of the legal structure of deloitte llp and its subsidiaries
#  all qualified applicants will receive consideration for employment without regard to race color religion sex sexual orientation gender identity national origin age disability or protected veteran status or any other legally protected basis in accordance with applicable law
#  deloitte will consider for employment all qualified applicants including those with criminal histories in a manner consistent with the requirements of applicable state and local laws
#  see notices of various banthebox laws where available
#  requisition code
#
# Job Description 14:
#  design develop and test high quality software features by understanding user needs and implementing well designed code
#  follow and implement the code with standards and best practices
#  good communication sense of urgency  a good team player
#
# skills  experience
#  a bachelors degree in computer science engineering information technology or equivalent experience
#   years professional software development experience with php on wordpress in an enterprise environment
#  development experience in wordpress wp plugins php htmlcss  java script
#  mysql linux git
#  strong analytical and debugging skills testing and familiarity with common debugging tools
#
# Job Description 15:
# if youre passionate about building a better future for individuals communities and our countryand youre committed to working hard to play your part in building that futureconsider wgu as the next step in your career
#
# driven by a mission to expand access to higher education through online competencybased degree programs wgu is also committed to being a great place to work for a diverse workforce of studentfocused professionals the university has pioneered a new way to learn in the  century one that has received praise from academic industry government and media leaders whatever your role working for wgu gives you a part to play in helping students graduate creating a better tomorrow for themselves and their families
#
# position summary
#
# the web designer works on the creative side of producing a website they are responsible for designing visual elements for use online reflecting our branding and design aesthetic they create layouts for landing pages product pages homepages category pages and other areas of the website ensuring their designs are emotionally compelling unique and on strategy the position is remote
#
# essential functions and responsibilities
#
# this person will be part our creative team consisting of over  talented people including copywriters video editors and graphic designers the position will report to the sr manager of brand design this position works closely with the greater marketing team to create pages that will help to increase engagement and conversion within our newly designed website environment
#
# their duties and responsibilities may include
#  take a key role in the design and layout of our consumer facing webpages
#  creating wireframes for initial review by the greater marketing team to make sure they map to the overall marketing strategy
#  be able to understand user personas and have ideas for which kinds of content would be the most effective eg videos infographics header images charts etc
#  create highfidelity comps in at least one webpage mockup tools such as figma sketch photoshop adobexd invision webflow etc for the visual layout and design of web pages the ability to program is not necessary as this role is more design oriented
#  experience with web content management systems and page building tools we currently use adobe aem version
#  work within our newly developed component library and customize components as needed
#  advocate a passion for applying user feedback through various testing methods and be able to iterate based on design feedback
#  collaborate with other designers front and backend development teams content owners project managers and other internal teams to create great user experiences
#  liaising with copywriters graphic designers developers and project management to ensure that tasks are completed on time
#  create and lead best uiux practices and disciplines and help ensure these guidelines are followed throughout the implementation phase
#
# knowledge skill and abilities
#  proficient in the use of the adobe creative suite
#  ability to prototype designs in interactive formats using figma adobexd sketch or other similar tools
#  understanding of best practices in designing for responsive websites with a focus on mobile first
#  highlevel understanding of visual design principles including color optimization layout hierarchy typography and composition
#  effectively communicate your designs to developers and other key stakeholders
#
# qualifications
#
# minimum qualifications
#   years experience working as a uxui designer including design development implementation and production deployment
#  a portfolio of examples of webpage design
#
# as an equal opportunity employer wgu recognizes that our strength lies in our people we are committed to diversity

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from transformers import BertTokenizer, TFBertModel

# %%
# Sample job descriptions
job_descriptions = [
    "Looking for a biology teacher with experience in STEM education.",
    "Seeking a clinical lab manager with strong molecular diagnostics skills.",
    "Hiring a quality control technician with experience in TCA/E coordination.",
]

# Sample CV details (embeddings should be calculated)
cv_details = [
    "I am a biology teacher with a background in STEM education.",
    "I have extensive experience as a clinical lab manager in molecular diagnostics.",
    "I am a quality control technician with expertise in TCA/E coordination.",
    "I have skills in biology education and experience as a lab manager.",
    "Experienced quality control technician with a background in molecular diagnostics.",
]

# Initialize BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = TFBertModel.from_pretrained('bert-base-uncased')

# Tokenize and encode job descriptions
job_desc_tokens = tokenizer(job_descriptions, padding=True, truncation=True, return_tensors="tf", max_length=128)
job_desc_embeddings = model(job_desc_tokens)['last_hidden_state'].numpy().mean(axis=1)


# Tokenize and encode CV details
cv_tokens = tokenizer(cv_details, padding=True, truncation=True, return_tensors="tf", max_length=128)
cv_embeddings = model(cv_tokens)['last_hidden_state'].numpy().mean(axis=1)


# Calculate cosine similarity between job descriptions and CVs
similarities = cosine_similarity(job_desc_embeddings, cv_embeddings)

# Rank CVs based on similarity for each job description
top_cv_indices = np.argsort(similarities, axis=1)[:, -5:][:, ::-1]


# Print the top 5 CVs for each job description
for i, job_desc in enumerate(job_descriptions):
    print(f"Top 5 CVs for Job Description {i+1} - {job_desc}\n")
    for j, cv_idx in enumerate(top_cv_indices[i]):
        print(f"CV {j+1} - Similarity: {similarities[i, cv_idx]}")
        print(cv_details[cv_idx])
        print("-" * 50)
    print("=" * 50)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Top 5 CVs for Job Description 1 - Looking for a biology teacher with experience in STEM education.
#
# CV 1 - Similarity: 0.8201055526733398
# I am a biology teacher with a background in STEM education.
# --------------------------------------------------
# CV 2 - Similarity: 0.7896248698234558
# I have skills in biology education and experience as a lab manager.
# --------------------------------------------------
# CV 3 - Similarity: 0.7731002569198608
# Experienced quality control technician with a background in molecular diagnostics.
# --------------------------------------------------
# CV 4 - Similarity: 0.7311567664146423
# I have extensive experience as a clinical lab manager in molecular diagnostics.
# --------------------------------------------------
# CV 5 - Similarity: 0.6833124756813049
# I am a quality control technician with expertise in TCA/E coordination.
# --------------------------------------------------
# ==================================================
# Top 5 CVs for Job Description 2 - Seeking a clinical lab manager with strong molecular diagnostics skills.
#
# CV 1 - Similarity: 0.870723307132721
# Experienced quality control technician with a background in molecular diagnostics.
# --------------------------------------------------
# CV 2 - Similarity: 0.82206130027771
# I have extensive experience as a clinical lab manager in molecular diagnostics.
# --------------------------------------------------
# CV 3 - Similarity: 0.7850565314292908
# I have skills in biology education and experience as a lab manager.
# --------------------------------------------------
# CV 4 - Similarity: 0.7443259954452515
# I am a quality control technician with expertise in TCA/E coordination.
# --------------------------------------------------
# CV 5 - Similarity: 0.6870715618133545
# I am a biology teacher with a background in STEM education.
# --------------------------------------------------
# ==================================================
# Top 5 CVs for Job Description 3 - Hiring a quality control technician with experience in TCA/E coordination.
#
# CV 1 - Similarity: 0.8818155527114868
# I am a quality control technician with expertise in TCA/E coordination.
# --------------------------------------------------
# CV 2 - Similarity: 0.8557876944541931
# Experienced quality control technician with a background in molecular diagnostics.
# --------------------------------------------------
# CV 3 - Similarity: 0.7438289523124695
# I have extensive experience as a clinical lab manager in molecular diagnostics.
# --------------------------------------------------
# CV 4 - Similarity: 0.7422343492507935
# I have skills in biology education and experience as a lab manager.
# --------------------------------------------------
# CV 5 - Similarity: 0.6545674800872803
# I am a biology teacher with a background in STEM education.
# --------------------------------------------------
# ==================================================

# %%
# !pip install pymupdf
# Out:
# Requirement already satisfied: pymupdf in c:\users\lenovo\anaconda3\lib\site-packages (1.23.3)
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: PyMuPDFb==1.23.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pymupdf) (1.23.3)

# %%
import os
import fitz  # PyMuPDF
from transformers import DistilBertTokenizer, DistilBertModel
import torch
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from datasets import load_dataset

# Function to preprocess and tokenize text
def preprocess_text(text, tokenizer, max_length):
    inputs = tokenizer(text, max_length=max_length, padding="max_length", truncation=True, return_tensors="pt")
    return inputs

# Function to extract text from PDF using PyMuPDF
def extract_text_from_pdf(pdf_path):
    text = ''
    try:
        # Open the PDF file
        pdf_document = fitz.open(pdf_path)
        for page_num in range(pdf_document.page_count):
            page = pdf_document.load_page(page_num)
            text += page.get_text()
    except Exception as e:
        print(f"Failed to extract text from {pdf_path}: {str(e)}")
    
    return text

# Load DistilBERT tokenizer and model
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
model = DistilBertModel.from_pretrained("distilbert-base-uncased")

# Define the path to the 'data' folder containing CVs
data_folder = r'C:\Users\Lenovo\Downloads\archive (1)\data\data' # Replace with the actual path to your 'data' folder

# Load the job descriptions dataset
# Load the job descriptions dataset
dataset = load_dataset("jacob-hugging-face/job-descriptions")
job_descriptions = dataset["train"]["job_description"]


# Initialize a dictionary to store CV embeddings
cv_embeddings = {}

# Iterate through job folders and process CVs
for job_folder in os.listdir(data_folder):
    print(f"Processing job folder: {job_folder}")
    job_folder_path = os.path.join(data_folder, job_folder)
    cv_embeddings[job_folder] = []

    # Get PDF files for the current job
    pdf_files = [os.path.join(job_folder_path, file) for file in os.listdir(job_folder_path) if file.endswith(".pdf")]

    # Process each CV for the current job
    for pdf_file in pdf_files:
        # Extract text from CV PDF using PyMuPDF
        text = extract_text_from_pdf(pdf_file)

        # Tokenize and preprocess CV text
        cv_tokens = preprocess_text(text, tokenizer, max_length=128)

        # Calculate embeddings
        with torch.no_grad():
            output = model(**cv_tokens)
        embeddings = output.last_hidden_state.mean(dim=1)  # Mean pooling over tokens
        cv_embeddings[job_folder].append(embeddings)

# Process job descriptions and calculate embeddings
job_description_embeddings = {}
for idx, description in enumerate(job_descriptions):
    print(f"Processing job description {idx + 1}/{len(job_descriptions)}")
    inputs = preprocess_text(description, tokenizer, max_length=128)
    with torch.no_grad():
        output = model(**inputs)
    embeddings = output.last_hidden_state.mean(dim=1)  # Mean pooling over tokens
    job_description_embeddings[idx] = embeddings

# Rank CVs for each job description based on cosine similarity
top_cv_matches = {}
for job_idx, job_description_embedding in job_description_embeddings.items():
    similarity_scores = []
    for cv_folder, cv_embeddings_list in cv_embeddings.items():
        for cv_embedding in cv_embeddings_list:
            similarity = cosine_similarity(job_description_embedding, cv_embedding)
            similarity_scores.append((cv_folder, similarity.item()))

    # Sort CVs by similarity score
    similarity_scores.sort(key=lambda x: x[1], reverse=True)
    top_cv_matches[job_descriptions[job_idx]] = similarity_scores[:5]

# Display top 5 CV matches for each job description
for job_description, cv_matches in top_cv_matches.items():
    print(f"\nTop 5 CV matches for Job Description:\n{job_description}")
    for cv_folder, similarity in cv_matches:
        print(f"Similarity Score: {similarity:.3f}")
        print(f"CV Folder: {cv_folder}")
# Out:
# Processing job folder: ACCOUNTANT
# Processing job folder: ADVOCATE
# Processing job folder: AGRICULTURE
# Processing job folder: APPAREL
# Processing job folder: ARTS
# Processing job folder: AUTOMOBILE
# Processing job folder: AVIATION
# Processing job folder: BANKING
# Processing job folder: BPO
# Processing job folder: BUSINESS-DEVELOPMENT
# Processing job folder: CHEF
# Processing job folder: CONSTRUCTION
# Processing job folder: CONSULTANT
# Processing job folder: DESIGNER
# Processing job folder: DIGITAL-MEDIA
# Processing job folder: ENGINEERING
# Processing job folder: FINANCE
# Processing job folder: FITNESS
# Processing job folder: HEALTHCARE
# Processing job folder: HR
# Processing job folder: INFORMATION-TECHNOLOGY
# Processing job folder: PUBLIC-RELATIONS
# Processing job folder: SALES
# Processing job folder: TEACHER
# Processing job description 1/853
# Processing job description 2/853
# Processing job description 3/853
# Processing job description 4/853
# Processing job description 5/853
# Processing job description 6/853
# Processing job description 7/853
# Processing job description 8/853
# Processing job description 9/853
# Processing job description 10/853
# Processing job description 11/853
# Processing job description 12/853
# Processing job description 13/853
# Processing job description 14/853
# Processing job description 15/853
# Processing job description 16/853
# Processing job description 17/853
# Processing job description 18/853
# Processing job description 19/853
# Processing job description 20/853
# Processing job description 21/853
# Processing job description 22/853
# Processing job description 23/853
# Processing job description 24/853
# Processing job description 25/853
# Processing job description 26/853
# Processing job description 27/853
# Processing job description 28/853
# Processing job description 29/853
# Processing job description 30/853
# Processing job description 31/853
# Processing job description 32/853
# Processing job description 33/853
# Processing job description 34/853
# Processing job description 35/853
# Processing job description 36/853
# Processing job description 37/853
# Processing job description 38/853
# Processing job description 39/853
# Processing job description 40/853
# Processing job description 41/853
# Processing job description 42/853
# Processing job description 43/853
# Processing job description 44/853
# Processing job description 45/853
# Processing job description 46/853
# Processing job description 47/853
# Processing job description 48/853
# Processing job description 49/853
# Processing job description 50/853
# Processing job description 51/853
# Processing job description 52/853
# Processing job description 53/853
# Processing job description 54/853
# Processing job description 55/853
# Processing job description 56/853
# Processing job description 57/853
# Processing job description 58/853
# Processing job description 59/853
# Processing job description 60/853
# Processing job description 61/853
# Processing job description 62/853
# Processing job description 63/853
# Processing job description 64/853
# Processing job description 65/853
# Processing job description 66/853
# Processing job description 67/853
# Processing job description 68/853
# Processing job description 69/853
# Processing job description 70/853
# Processing job description 71/853
# Processing job description 72/853
# Processing job description 73/853
# Processing job description 74/853
# Processing job description 75/853
# Processing job description 76/853
# Processing job description 77/853
# Processing job description 78/853
# Processing job description 79/853
# Processing job description 80/853
# Processing job description 81/853
# Processing job description 82/853
# Processing job description 83/853
# Processing job description 84/853
# Processing job description 85/853
# Processing job description 86/853
# Processing job description 87/853
# Processing job description 88/853
# Processing job description 89/853
# Processing job description 90/853
# Processing job description 91/853
# Processing job description 92/853
# Processing job description 93/853
# Processing job description 94/853
# Processing job description 95/853
# Processing job description 96/853
# Processing job description 97/853
# Processing job description 98/853
# Processing job description 99/853
# Processing job description 100/853
# Processing job description 101/853
# Processing job description 102/853
# Processing job description 103/853
# Processing job description 104/853
# Processing job description 105/853
# Processing job description 106/853
# Processing job description 107/853
# Processing job description 108/853
# Processing job description 109/853
# Processing job description 110/853
# Processing job description 111/853
# Processing job description 112/853
# Processing job description 113/853
# Processing job description 114/853
# Processing job description 115/853
# Processing job description 116/853
# Processing job description 117/853
# Processing job description 118/853
# Processing job description 119/853
# Processing job description 120/853
# Processing job description 121/853
# Processing job description 122/853
# Processing job description 123/853
# Processing job description 124/853
# Processing job description 125/853
# Processing job description 126/853
# Processing job description 127/853
# Processing job description 128/853
# Processing job description 129/853
# Processing job description 130/853
# Processing job description 131/853
# Processing job description 132/853
# Processing job description 133/853
# Processing job description 134/853
# Processing job description 135/853
# Processing job description 136/853
# Processing job description 137/853
# Processing job description 138/853
# Processing job description 139/853
# Processing job description 140/853
# Processing job description 141/853
# Processing job description 142/853
# Processing job description 143/853
# Processing job description 144/853
# Processing job description 145/853
# Processing job description 146/853
# Processing job description 147/853
# Processing job description 148/853
# Processing job description 149/853
# Processing job description 150/853
# Processing job description 151/853
# Processing job description 152/853
# Processing job description 153/853
# Processing job description 154/853
# Processing job description 155/853
# Processing job description 156/853
# Processing job description 157/853
# Processing job description 158/853
# Processing job description 159/853
# Processing job description 160/853
# Processing job description 161/853
# Processing job description 162/853
# Processing job description 163/853
# Processing job description 164/853
# Processing job description 165/853
# Processing job description 166/853
# Processing job description 167/853
# Processing job description 168/853
# Processing job description 169/853
# Processing job description 170/853
# Processing job description 171/853
# Processing job description 172/853
# Processing job description 173/853
# Processing job description 174/853
# Processing job description 175/853
# Processing job description 176/853
# Processing job description 177/853
# Processing job description 178/853
# Processing job description 179/853
# Processing job description 180/853
# Processing job description 181/853
# Processing job description 182/853
# Processing job description 183/853
# Processing job description 184/853
# Processing job description 185/853
# Processing job description 186/853
# Processing job description 187/853
# Processing job description 188/853
# Processing job description 189/853
# Processing job description 190/853
# Processing job description 191/853
# Processing job description 192/853
# Processing job description 193/853
# Processing job description 194/853
# Processing job description 195/853
# Processing job description 196/853
# Processing job description 197/853
# Processing job description 198/853
# Processing job description 199/853
# Processing job description 200/853
# Processing job description 201/853
# Processing job description 202/853
# Processing job description 203/853
# Processing job description 204/853
# Processing job description 205/853
# Processing job description 206/853
# Processing job description 207/853
# Processing job description 208/853
# Processing job description 209/853
# Processing job description 210/853
# Processing job description 211/853
# Processing job description 212/853
# Processing job description 213/853
# Processing job description 214/853
# Processing job description 215/853
# Processing job description 216/853
# Processing job description 217/853
# Processing job description 218/853
# Processing job description 219/853
# Processing job description 220/853
# Processing job description 221/853
# Processing job description 222/853
# Processing job description 223/853
# Processing job description 224/853
# Processing job description 225/853
# Processing job description 226/853
# Processing job description 227/853
# Processing job description 228/853
# Processing job description 229/853
# Processing job description 230/853
# Processing job description 231/853
# Processing job description 232/853
# Processing job description 233/853
# Processing job description 234/853
# Processing job description 235/853
# Processing job description 236/853
# Processing job description 237/853
# Processing job description 238/853
# Processing job description 239/853
# Processing job description 240/853
# Processing job description 241/853
# Processing job description 242/853
# Processing job description 243/853
# Processing job description 244/853
# Processing job description 245/853
# Processing job description 246/853
# Processing job description 247/853
# Processing job description 248/853
# Processing job description 249/853
# Processing job description 250/853
# Processing job description 251/853
# Processing job description 252/853
# Processing job description 253/853
# Processing job description 254/853
# Processing job description 255/853
# Processing job description 256/853
# Processing job description 257/853
# Processing job description 258/853
# Processing job description 259/853
# Processing job description 260/853
# Processing job description 261/853
# Processing job description 262/853
# Processing job description 263/853
# Processing job description 264/853
# Processing job description 265/853
# Processing job description 266/853
# Processing job description 267/853
# Processing job description 268/853
# Processing job description 269/853
# Processing job description 270/853
# Processing job description 271/853
# Processing job description 272/853
# Processing job description 273/853
# Processing job description 274/853
# Processing job description 275/853
# Processing job description 276/853
# Processing job description 277/853
# Processing job description 278/853
# Processing job description 279/853
# Processing job description 280/853
# Processing job description 281/853
# Processing job description 282/853
# Processing job description 283/853
# Processing job description 284/853
# Processing job description 285/853
# Processing job description 286/853
# Processing job description 287/853
# Processing job description 288/853
# Processing job description 289/853
# Processing job description 290/853
# Processing job description 291/853
# Processing job description 292/853
# Processing job description 293/853
# Processing job description 294/853
# Processing job description 295/853
# Processing job description 296/853
# Processing job description 297/853
# Processing job description 298/853
# Processing job description 299/853
# Processing job description 300/853
# Processing job description 301/853
# Processing job description 302/853
# Processing job description 303/853
# Processing job description 304/853
# Processing job description 305/853
# Processing job description 306/853
# Processing job description 307/853
# Processing job description 308/853
# Processing job description 309/853
# Processing job description 310/853
# Processing job description 311/853
# Processing job description 312/853
# Processing job description 313/853
# Processing job description 314/853
# Processing job description 315/853
# Processing job description 316/853
# Processing job description 317/853
# Processing job description 318/853
# Processing job description 319/853
# Processing job description 320/853
# Processing job description 321/853
# Processing job description 322/853
# Processing job description 323/853
# Processing job description 324/853
# Processing job description 325/853
# Processing job description 326/853
# Processing job description 327/853
# Processing job description 328/853
# Processing job description 329/853
# Processing job description 330/853
# Processing job description 331/853
# Processing job description 332/853
# Processing job description 333/853
# Processing job description 334/853
# Processing job description 335/853
# Processing job description 336/853
# Processing job description 337/853
# Processing job description 338/853
# Processing job description 339/853
# Processing job description 340/853
# Processing job description 341/853
# Processing job description 342/853
# Processing job description 343/853
# Processing job description 344/853
# Processing job description 345/853
# Processing job description 346/853
# Processing job description 347/853
# Processing job description 348/853
# Processing job description 349/853
# Processing job description 350/853
# Processing job description 351/853
# Processing job description 352/853
# Processing job description 353/853
# Processing job description 354/853
# Processing job description 355/853
# Processing job description 356/853
# Processing job description 357/853
# Processing job description 358/853
# Processing job description 359/853
# Processing job description 360/853
# Processing job description 361/853
# Processing job description 362/853
# Processing job description 363/853
# Processing job description 364/853
# Processing job description 365/853
# Processing job description 366/853
# Processing job description 367/853
# Processing job description 368/853
# Processing job description 369/853
# Processing job description 370/853
# Processing job description 371/853
# Processing job description 372/853
# Processing job description 373/853
# Processing job description 374/853
# Processing job description 375/853
# Processing job description 376/853
# Processing job description 377/853
# Processing job description 378/853
# Processing job description 379/853
# Processing job description 380/853
# Processing job description 381/853
# Processing job description 382/853
# Processing job description 383/853
# Processing job description 384/853
# Processing job description 385/853
# Processing job description 386/853
# Processing job description 387/853
# Processing job description 388/853
# Processing job description 389/853
# Processing job description 390/853
# Processing job description 391/853
# Processing job description 392/853
# Processing job description 393/853
# Processing job description 394/853
# Processing job description 395/853
# Processing job description 396/853
# Processing job description 397/853
# Processing job description 398/853
# Processing job description 399/853
# Processing job description 400/853
# Processing job description 401/853
# Processing job description 402/853
# Processing job description 403/853
# Processing job description 404/853
# Processing job description 405/853
# Processing job description 406/853
# Processing job description 407/853
# Processing job description 408/853
# Processing job description 409/853
# Processing job description 410/853
# Processing job description 411/853
# Processing job description 412/853
# Processing job description 413/853
# Processing job description 414/853
# Processing job description 415/853
# Processing job description 416/853
# Processing job description 417/853
# Processing job description 418/853
# Processing job description 419/853
# Processing job description 420/853
# Processing job description 421/853
# Processing job description 422/853
# Processing job description 423/853
# Processing job description 424/853
# Processing job description 425/853
# Processing job description 426/853
# Processing job description 427/853
# Processing job description 428/853
# Processing job description 429/853
# Processing job description 430/853
# Processing job description 431/853
# Processing job description 432/853
# Processing job description 433/853
# Processing job description 434/853
# Processing job description 435/853
# Processing job description 436/853
# Processing job description 437/853
# Processing job description 438/853
# Processing job description 439/853
# Processing job description 440/853
# Processing job description 441/853
# Processing job description 442/853
# Processing job description 443/853
# Processing job description 444/853
# Processing job description 445/853
# Processing job description 446/853
# Processing job description 447/853
# Processing job description 448/853
# Processing job description 449/853
# Processing job description 450/853
# Processing job description 451/853
# Processing job description 452/853
# Processing job description 453/853
# Processing job description 454/853
# Processing job description 455/853
# Processing job description 456/853
# Processing job description 457/853
# Processing job description 458/853
# Processing job description 459/853
# Processing job description 460/853
# Processing job description 461/853
# Processing job description 462/853
# Processing job description 463/853
# Processing job description 464/853
# Processing job description 465/853
# Processing job description 466/853
# Processing job description 467/853
# Processing job description 468/853
# Processing job description 469/853
# Processing job description 470/853
# Processing job description 471/853
# Processing job description 472/853
# Processing job description 473/853
# Processing job description 474/853
# Processing job description 475/853
# Processing job description 476/853
# Processing job description 477/853
# Processing job description 478/853
# Processing job description 479/853
# Processing job description 480/853
# Processing job description 481/853
# Processing job description 482/853
# Processing job description 483/853
# Processing job description 484/853
# Processing job description 485/853
# Processing job description 486/853
# Processing job description 487/853
# Processing job description 488/853
# Processing job description 489/853
# Processing job description 490/853
# Processing job description 491/853
# Processing job description 492/853
# Processing job description 493/853
# Processing job description 494/853
# Processing job description 495/853
# Processing job description 496/853
# Processing job description 497/853
# Processing job description 498/853
# Processing job description 499/853
# Processing job description 500/853
# Processing job description 501/853
# Processing job description 502/853
# Processing job description 503/853
# Processing job description 504/853
# Processing job description 505/853
# Processing job description 506/853
# Processing job description 507/853
# Processing job description 508/853
# Processing job description 509/853
# Processing job description 510/853
# Processing job description 511/853
# Processing job description 512/853
# Processing job description 513/853
# Processing job description 514/853
# Processing job description 515/853
# Processing job description 516/853
# Processing job description 517/853
# Processing job description 518/853
# Processing job description 519/853
# Processing job description 520/853
# Processing job description 521/853
# Processing job description 522/853
# Processing job description 523/853
# Processing job description 524/853
# Processing job description 525/853
# Processing job description 526/853
# Processing job description 527/853
# Processing job description 528/853
# Processing job description 529/853
# Processing job description 530/853
# Processing job description 531/853
# Processing job description 532/853
# Processing job description 533/853
# Processing job description 534/853
# Processing job description 535/853
# Processing job description 536/853
# Processing job description 537/853
# Processing job description 538/853
# Processing job description 539/853
# Processing job description 540/853
# Processing job description 541/853
# Processing job description 542/853
# Processing job description 543/853
# Processing job description 544/853
# Processing job description 545/853
# Processing job description 546/853
# Processing job description 547/853
# Processing job description 548/853
# Processing job description 549/853
# Processing job description 550/853
# Processing job description 551/853
# Processing job description 552/853
# Processing job description 553/853
# Processing job description 554/853
# Processing job description 555/853
# Processing job description 556/853
# Processing job description 557/853
# Processing job description 558/853
# Processing job description 559/853
# Processing job description 560/853
# Processing job description 561/853
# Processing job description 562/853
# Processing job description 563/853
# Processing job description 564/853
# Processing job description 565/853
# Processing job description 566/853
# Processing job description 567/853
# Processing job description 568/853
# Processing job description 569/853
# Processing job description 570/853
# Processing job description 571/853
# Processing job description 572/853
# Processing job description 573/853
# Processing job description 574/853
# Processing job description 575/853
# Processing job description 576/853
# Processing job description 577/853
# Processing job description 578/853
# Processing job description 579/853
# Processing job description 580/853
# Processing job description 581/853
# Processing job description 582/853
# Processing job description 583/853
# Processing job description 584/853
# Processing job description 585/853
# Processing job description 586/853
# Processing job description 587/853
# Processing job description 588/853
# Processing job description 589/853
# Processing job description 590/853
# Processing job description 591/853
# Processing job description 592/853
# Processing job description 593/853
# Processing job description 594/853
# Processing job description 595/853
# Processing job description 596/853
# Processing job description 597/853
# Processing job description 598/853
# Processing job description 599/853
# Processing job description 600/853
# Processing job description 601/853
# Processing job description 602/853
# Processing job description 603/853
# Processing job description 604/853
# Processing job description 605/853
# Processing job description 606/853
# Processing job description 607/853
# Processing job description 608/853
# Processing job description 609/853
# Processing job description 610/853
# Processing job description 611/853
# Processing job description 612/853
# Processing job description 613/853
# Processing job description 614/853
# Processing job description 615/853
# Processing job description 616/853
# Processing job description 617/853
# Processing job description 618/853
# Processing job description 619/853
# Processing job description 620/853
# Processing job description 621/853
# Processing job description 622/853
# Processing job description 623/853
# Processing job description 624/853
# Processing job description 625/853
# Processing job description 626/853
# Processing job description 627/853
# Processing job description 628/853
# Processing job description 629/853
# Processing job description 630/853
# Processing job description 631/853
# Processing job description 632/853
# Processing job description 633/853
# Processing job description 634/853
# Processing job description 635/853
# Processing job description 636/853
# Processing job description 637/853
# Processing job description 638/853
# Processing job description 639/853
# Processing job description 640/853
# Processing job description 641/853
# Processing job description 642/853
# Processing job description 643/853
# Processing job description 644/853
# Processing job description 645/853
# Processing job description 646/853
# Processing job description 647/853
# Processing job description 648/853
# Processing job description 649/853
# Processing job description 650/853
# Processing job description 651/853
# Processing job description 652/853
# Processing job description 653/853
# Processing job description 654/853
# Processing job description 655/853
# Processing job description 656/853
# Processing job description 657/853
# Processing job description 658/853
# Processing job description 659/853
# Processing job description 660/853
# Processing job description 661/853
# Processing job description 662/853
# Processing job description 663/853
# Processing job description 664/853
# Processing job description 665/853
# Processing job description 666/853
# Processing job description 667/853
# Processing job description 668/853
# Processing job description 669/853
# Processing job description 670/853
# Processing job description 671/853
# Processing job description 672/853
# Processing job description 673/853
# Processing job description 674/853
# Processing job description 675/853
# Processing job description 676/853
# Processing job description 677/853
# Processing job description 678/853
# Processing job description 679/853
# Processing job description 680/853
# Processing job description 681/853
# Processing job description 682/853
# Processing job description 683/853
# Processing job description 684/853
# Processing job description 685/853
# Processing job description 686/853
# Processing job description 687/853
# Processing job description 688/853
# Processing job description 689/853
# Processing job description 690/853
# Processing job description 691/853
# Processing job description 692/853
# Processing job description 693/853
# Processing job description 694/853
# Processing job description 695/853
# Processing job description 696/853
# Processing job description 697/853
# Processing job description 698/853
# Processing job description 699/853
# Processing job description 700/853
# Processing job description 701/853
# Processing job description 702/853
# Processing job description 703/853
# Processing job description 704/853
# Processing job description 705/853
# Processing job description 706/853
# Processing job description 707/853
# Processing job description 708/853
# Processing job description 709/853
# Processing job description 710/853
# Processing job description 711/853
# Processing job description 712/853
# Processing job description 713/853
# Processing job description 714/853
# Processing job description 715/853
# Processing job description 716/853
# Processing job description 717/853
# Processing job description 718/853
# Processing job description 719/853
# Processing job description 720/853
# Processing job description 721/853
# Processing job description 722/853
# Processing job description 723/853
# Processing job description 724/853
# Processing job description 725/853
# Processing job description 726/853
# Processing job description 727/853
# Processing job description 728/853
# Processing job description 729/853
# Processing job description 730/853
# Processing job description 731/853
# Processing job description 732/853
# Processing job description 733/853
# Processing job description 734/853
# Processing job description 735/853
# Processing job description 736/853
# Processing job description 737/853
# Processing job description 738/853
# Processing job description 739/853
# Processing job description 740/853
# Processing job description 741/853
# Processing job description 742/853
# Processing job description 743/853
# Processing job description 744/853
# Processing job description 745/853
# Processing job description 746/853
# Processing job description 747/853
# Processing job description 748/853
# Processing job description 749/853
# Processing job description 750/853
# Processing job description 751/853
# Processing job description 752/853
# Processing job description 753/853
# Processing job description 754/853
# Processing job description 755/853
# Processing job description 756/853
# Processing job description 757/853
# Processing job description 758/853
# Processing job description 759/853
# Processing job description 760/853
# Processing job description 761/853
# Processing job description 762/853
# Processing job description 763/853
# Processing job description 764/853
# Processing job description 765/853
# Processing job description 766/853
# Processing job description 767/853
# Processing job description 768/853
# Processing job description 769/853
# Processing job description 770/853
# Processing job description 771/853
# Processing job description 772/853
# Processing job description 773/853
# Processing job description 774/853
# Processing job description 775/853
# Processing job description 776/853
# Processing job description 777/853
# Processing job description 778/853
# Processing job description 779/853
# Processing job description 780/853
# Processing job description 781/853
# Processing job description 782/853
# Processing job description 783/853
# Processing job description 784/853
# Processing job description 785/853
# Processing job description 786/853
# Processing job description 787/853
# Processing job description 788/853
# Processing job description 789/853
# Processing job description 790/853
# Processing job description 791/853
# Processing job description 792/853
# Processing job description 793/853
# Processing job description 794/853
# Processing job description 795/853
# Processing job description 796/853
# Processing job description 797/853
# Processing job description 798/853
# Processing job description 799/853
# Processing job description 800/853
# Processing job description 801/853
# Processing job description 802/853
# Processing job description 803/853
# Processing job description 804/853
# Processing job description 805/853
# Processing job description 806/853
# Processing job description 807/853
# Processing job description 808/853
# Processing job description 809/853
# Processing job description 810/853
# Processing job description 811/853
# Processing job description 812/853
# Processing job description 813/853
# Processing job description 814/853
# Processing job description 815/853
# Processing job description 816/853
# Processing job description 817/853
# Processing job description 818/853
# Processing job description 819/853
# Processing job description 820/853
# Processing job description 821/853
# Processing job description 822/853
# Processing job description 823/853
# Processing job description 824/853
# Processing job description 825/853
# Processing job description 826/853
# Processing job description 827/853
# Processing job description 828/853
# Processing job description 829/853
# Processing job description 830/853
# Processing job description 831/853
# Processing job description 832/853
# Processing job description 833/853
# Processing job description 834/853
# Processing job description 835/853
# Processing job description 836/853
# Processing job description 837/853
# Processing job description 838/853
# Processing job description 839/853
# Processing job description 840/853
# Processing job description 841/853
# Processing job description 842/853
# Processing job description 843/853
# Processing job description 844/853
# Processing job description 845/853
# Processing job description 846/853
# Processing job description 847/853
# Processing job description 848/853
# Processing job description 849/853
# Processing job description 850/853
# Processing job description 851/853
# Processing job description 852/853
# Processing job description 853/853
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
